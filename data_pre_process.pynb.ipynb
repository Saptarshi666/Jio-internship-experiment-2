# %%
import zipfile
import os

def unzip_file(zip_path, extract_to):
    with zipfile.ZipFile(zip_path, 'r') as zip_ref:
        zip_ref.extractall(extract_to)

# Paths to your zip files and extraction directories
zip_paths = [
    r'C:\Users\deeps\VSCodeProjects\Jio_internship_project_2\Tamil_master.zip',
    r'C:\Users\deeps\VSCodeProjects\Jio_internship_project_2\Malayalam_master.zip',
    r'C:\Users\deeps\VSCodeProjects\Jio_internship_project_2\Malayalam_master.zip',
    r'C:\Users\deeps\VSCodeProjects\Jio_internship_project_2\Tamil_master.zip',
    r'C:\Users\deeps\VSCodeProjects\Jio_internship_project_2\Telugu_master.zip'
]

# Extract all zip files to their respective directories
for zip_path in zip_paths:
    extract_to = os.path.splitext(zip_path)[0]  # Extract to a folder with the same name as the zip file
    unzip_file(zip_path, extract_to)

# %%
pip install librosa

# %%
import librosa
import csv
import os
import numpy as np

def remove_silence(audio, sr, top_db=20):
    """
    Remove silent intervals from the audio signal.
    :param audio: Audio signal (numpy array)
    :param sr: Sampling rate
    :param top_db: The threshold (in decibels) below reference to consider as silence
    :return: Audio signal without silence
    """
    non_silent_intervals = librosa.effects.split(audio, top_db=top_db)
    non_silent_audio = np.concatenate([audio[start:end] for start, end in non_silent_intervals])
    return non_silent_audio

def extract_formants(audio, sr, frame_size=2048, lpc_order=8):
    """
    Extract the first two formants from the audio signal.
    :param audio: Audio signal (numpy array)
    :param sr: Sampling rate
    :param frame_size: Size of the frame for LPC analysis
    :param lpc_order: Order of the LPC analysis
    :return: Formants (first two formants)
    """
    formants = []
    for i in range(0, len(audio) - frame_size, frame_size):
        frame = audio[i:i + frame_size] * np.hamming(frame_size)
        A = librosa.lpc(frame, order=lpc_order)
        roots = np.roots(A)
        roots = [r for r in roots if np.imag(r) >= 0]  # Keep only positive imaginary roots
        angles = np.angle(roots)
        formants.extend(np.abs(np.cos(angles)) * sr / (2 * np.pi))
    
    formants = np.array(formants)
    if formants.size > 0:
        # Handle cases where formants array is not divisible by 2
        num_formants = formants.size // 2 * 2  # Ensure the number is even
        formants = formants[:num_formants]  # Trim excess if any
        formants = np.mean(formants.reshape(-1, 2), axis=0)  # Average formants across frames
    else:
        formants = np.zeros(2)  # Default to zeros if no formants are extracted
    
    return formants



def extract_features(audio, sr, output_label):
    # Remove silence from the audio
    audio = remove_silence(audio, sr)

    frame_size = int(0.03 * sr)
    hop_length = int(0.01 * sr)

    # Extract MFCC features
    mfcc = librosa.feature.mfcc(y=audio, sr=sr, n_mfcc=13, hop_length=hop_length, n_fft=frame_size).astype(np.float16)
    delta_mfcc = librosa.feature.delta(mfcc).astype(np.float16)
    delta2_mfcc = librosa.feature.delta(mfcc, order=2).astype(np.float16)

    # Extract Pitch (Fundamental Frequency) and HNR
    pitches, magnitudes = librosa.core.piptrack(y=audio, sr=sr, hop_length=hop_length, n_fft=frame_size)
    pitch = np.mean(pitches[pitches > 0]) if np.any(pitches > 0) else 0.0
    hnr = librosa.effects.harmonic(y=audio).mean()

    # Extract Formants
    formants = extract_formants(audio, sr)

    # Extract Spectral Features
    spectral_centroid = librosa.feature.spectral_centroid(y=audio, sr=sr, hop_length=hop_length).flatten().astype(np.float16)
    spectral_bandwidth = librosa.feature.spectral_bandwidth(y=audio, sr=sr, hop_length=hop_length).flatten().astype(np.float16)
    spectral_contrast = librosa.feature.spectral_contrast(y=audio, sr=sr, hop_length=hop_length).flatten().astype(np.float16)
    spectral_flatness = librosa.feature.spectral_flatness(y=audio, hop_length=hop_length).flatten().astype(np.float16)

    # Extract Zero-Crossing Rate
    zcr = librosa.feature.zero_crossing_rate(y=audio, hop_length=hop_length, frame_length=frame_size).flatten().astype(np.float16)

    # Extract RMS Energy
    rms = librosa.feature.rms(y=audio, hop_length=hop_length, frame_length=frame_size).flatten().astype(np.float16)

    # Extract Chroma Features
    chroma_stft = librosa.feature.chroma_stft(y=audio, sr=sr, hop_length=hop_length).flatten().astype(np.float16)

    num_frames = min(
        mfcc.shape[1],
        delta_mfcc.shape[1],
        delta2_mfcc.shape[1],
        len(zcr),
        len(rms),
        len(spectral_centroid),
        len(spectral_bandwidth),
        len(spectral_contrast),
        len(spectral_flatness),
        len(chroma_stft)
    )

    features = []
    for i in range(num_frames):
        frame_features = np.concatenate((
            mfcc[:, i],
            delta_mfcc[:, i],
            delta2_mfcc[:, i],
            [pitch],
            [hnr],
            formants,
            [zcr[i]],
            [rms[i]],
            [spectral_centroid[i]],
            [spectral_bandwidth[i]],
            spectral_contrast,
            [spectral_flatness[i]],
            chroma_stft
        ))
        features.append([frame_features, output_label])

    return features


def get_speaker_info(file_path):
    speaker_dict = {}
    with open(file_path, 'r') as f:
        next(f)  # Skip header
        for line in f:
            line_parts = line.split()
            gender = np.int8(1 if line_parts[1] == 'Male' else 0)
            age = round(float(line_parts[7]))
            age_group = [np.int8(0)] * 4
            age_index = min(max((age // 10) - 1, 0), 3)
            age_group[age_index] = np.int8(1)
            speaker_dict[line_parts[0]] = [gender] + age_group
    return speaker_dict

def write_header(writer):
    header = ['mfcc_' + str(i+1) for i in range(13)] + \
             ['delta_mfcc_' + str(i+1) for i in range(13)] + \
             ['delta2_mfcc_' + str(i+1) for i in range(13)] + \
             ['pitch', 'hnr', 'formant1', 'formant2', 'zcr', 'rms', 
              'spectral_centroid', 'spectral_bandwidth'] + \
             ['spectral_contrast_' + str(i+1) for i in range(7)] + \
             ['spectral_flatness'] + \
             ['chroma_stft_' + str(i+1) for i in range(12)] + \
             ['gender'] + ['age_group_' + str(i+1) for i in range(4)]
    writer.writerow(header)

def process_audio_files():
    source_dirs = [
        r'C:\Users\deeps\VSCodeProjects\Jio_internship_project_2\Tamil_master\Tamil_master\English_Tamil',
        r'C:\Users\deeps\VSCodeProjects\Jio_internship_project_2\Tamil_master\Tamil_master\Tamil',
        r'C:\Users\deeps\VSCodeProjects\Jio_internship_project_2\Malayalam_master\Malayalam_master\English_Malayalam',
        r'C:\Users\deeps\VSCodeProjects\Jio_internship_project_2\Malayalam_master\Malayalam_master\Malayalam',
        r'C:\Users\deeps\VSCodeProjects\Jio_internship_project_2\Hindi_master\Hindi_master\English_Hindi',
        r'C:\Users\deeps\VSCodeProjects\Jio_internship_project_2\Hindi_master\Hindi_master\Hindi',
        r'C:\Users\deeps\VSCodeProjects\Jio_internship_project_2\Telugu_master\Telugu_master\English_Telugu',
        r'C:\Users\deeps\VSCodeProjects\Jio_internship_project_2\Telugu_master\Telugu_master\Telugu',
        r'C:\Users\deeps\VSCodeProjects\Jio_internship_project_2\Kannada_master\Kannada_master\English_Kannada',
        r'C:\Users\deeps\VSCodeProjects\Jio_internship_project_2\Kannada_master\Kannada_master\Kannada'
    ]
    speaker_info_file = r'C:\Users\deeps\VSCodeProjects\Jio_internship_project_2\total_spkrinfo.list'
    speaker_dict = get_speaker_info(speaker_info_file)

    csv_file_number = 1
    record_count = 0
    max_records_per_file = 2000000

    csv_file = f'audio_features{csv_file_number}.csv'
    f = open(csv_file, 'a', newline='')
    writer = csv.writer(f)
    write_header(writer)

    for source_dir in source_dirs:
        for root, _, files in os.walk(source_dir):
            for file in files:
                if file.endswith('.wav'):
                    audio_file = os.path.join(root, file)
                    speaker_id = file[:8]
                    output_label = speaker_dict.get(speaker_id, [0] * 5)
                    audio, sr = librosa.load(audio_file, sr=None)
                    features = extract_features(audio, sr, output_label)
                    for frame_features in features:
                        writer.writerow(frame_features[0].tolist() + [frame_features[1][0]] + frame_features[1][1:])
                        record_count += 1

                        if record_count >= max_records_per_file:
                            f.close()
                            csv_file_number += 1
                            csv_file = f'audio_features{csv_file_number}.csv'
                            f = open(csv_file, 'a', newline='')
                            writer = csv.writer(f)
                            write_header(writer)
                            record_count = 0

                    print(f'Processed {file} - {record_count} records in current file')

    f.close()
    print("Feature extraction and CSV writing completed")

if __name__ == '__main__':
    process_audio_files()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[4], line 193
#     190     print("Feature extraction and CSV writing completed")
#     192 if __name__ == '__main__':
# --> 193     process_audio_files()
#
# Cell In[4], line 173, in process_audio_files()
#     171 output_label = speaker_dict.get(speaker_id, [0] * 5)
#     172 audio, sr = librosa.load(audio_file, sr=None)
# --> 173 features = extract_features(audio, sr, output_label)
#     174 for frame_features in features:
#     175     writer.writerow(frame_features[0].tolist() + [frame_features[1][0]] + frame_features[1][1:])
#
# Cell In[4], line 63, in extract_features(audio, sr, output_label)
#      60 hnr = librosa.effects.harmonic(y=audio).mean()
#      62 # Extract Formants
# ---> 63 formants = extract_formants(audio, sr)
#      65 # Extract Spectral Features
#      66 spectral_centroid = librosa.feature.spectral_centroid(y=audio, sr=sr, hop_length=hop_length).flatten().astype(np.float16)
#
# Cell In[4], line 38, in extract_formants(audio, sr, frame_size, lpc_order)
#      36 formants = np.array(formants)
#      37 if formants.size > 0:
# ---> 38     formants = np.mean(formants.reshape(-1, 2), axis=0)  # Average formants across frames
#      39 else:
#      40     formants = np.zeros(2)  # Default to zeros if no formants are extracted
#
# ValueError: cannot reshape array of size 265 into shape (2)

# %%
import librosa
import csv
import os
import numpy as np
from scipy.stats import skew, kurtosis

def safe_stats(array):
    """Replace inf and nan with zero and ensure valid statistics."""
    array = np.array(array)
    array[np.isnan(array)] = 0
    array[np.isinf(array)] = 0
    return array

def extract_features(audio, sr, output_label):
    frame_size = int(0.03 * sr)
    hop_length = int(0.01 * sr)

    # Extract MFCC features
    mfcc = librosa.feature.mfcc(y=audio, sr=sr, n_mfcc=13, hop_length=hop_length, n_fft=frame_size).astype(np.float16)
    delta_mfcc = librosa.feature.delta(mfcc).astype(np.float16)
    delta2_mfcc = librosa.feature.delta(mfcc, order=2).astype(np.float16)

    # Extract Pitch (Fundamental Frequency)
    pitches, _ = librosa.core.piptrack(y=audio, sr=sr, hop_length=hop_length, n_fft=frame_size)
    pitch = np.mean(pitches[pitches > 0]) if np.any(pitches > 0) else 0.0

    # Extract Spectral Features
    spectral_centroid = librosa.feature.spectral_centroid(y=audio, sr=sr, hop_length=hop_length).flatten().astype(np.float16)
    spectral_bandwidth = librosa.feature.spectral_bandwidth(y=audio, sr=sr, hop_length=hop_length).flatten().astype(np.float16)

    # Extract Zero-Crossing Rate
    zcr = librosa.feature.zero_crossing_rate(y=audio, hop_length=hop_length, frame_length=frame_size).flatten().astype(np.float16)

    # Extract RMS Energy
    rms = librosa.feature.rms(y=audio, hop_length=hop_length, frame_length=frame_size).flatten().astype(np.float16)

    # Statistics for MFCCs
    mfccs_stats = np.hstack([
        safe_stats(np.mean(mfcc, axis=1)),
        safe_stats(np.std(mfcc, axis=1)),
        safe_stats(skew(mfcc, axis=1)),
        safe_stats(kurtosis(mfcc, axis=1))
    ])

    # Ensure consistent lengths
    num_frames = min(
        mfcc.shape[1],
        delta_mfcc.shape[1],
        delta2_mfcc.shape[1],
        len(zcr),
        len(rms),
        len(spectral_centroid),
        len(spectral_bandwidth)
    )

    features = []
    for i in range(num_frames):
        frame_features = np.concatenate((
            mfcc[:, i],
            delta_mfcc[:, i],
            delta2_mfcc[:, i],
            [pitch],
            [zcr[i]],
            [rms[i]],
            [spectral_centroid[i]],
            [spectral_bandwidth[i]],
            mfccs_stats
        ))
        features.append([frame_features, output_label])

    return features

def get_speaker_info(file_path):
    speaker_dict = {}
    with open(file_path, 'r') as f:
        next(f)  # Skip header
        for line in f:
            line_parts = line.split()
            gender = np.int8(1 if line_parts[1] == 'Male' else 0)
            age = round(float(line_parts[7]))
            age_group = [np.int8(0)] * 4
            age_index = min(max((age // 10) - 1, 0), 3)
            age_group[age_index] = np.int8(1)
            speaker_dict[line_parts[0]] = [gender] + age_group
    return speaker_dict

def write_header(writer):
    header = ['mfcc_' + str(i+1) for i in range(13)] + \
             ['delta_mfcc_' + str(i+1) for i in range(13)] + \
             ['delta2_mfcc_' + str(i+1) for i in range(13)] + \
             ['pitch', 'zcr', 'rms', 'spectral_centroid', 'spectral_bandwidth'] + \
             ['mfcc_mean_' + str(i+1) for i in range(13)] + \
             ['mfcc_std_' + str(i+1) for i in range(13)] + \
             ['mfcc_skew_' + str(i+1) for i in range(13)] + \
             ['mfcc_kurt_' + str(i+1) for i in range(13)] + \
             ['gender'] + ['age_group_' + str(i+1) for i in range(4)]
    writer.writerow(header)

def process_audio_files():
    source_dirs = [
        r'C:\Users\deeps\VSCodeProjects\Jio_internship_project_2\Tamil_master\Tamil_master\English_Tamil',
        r'C:\Users\deeps\VSCodeProjects\Jio_internship_project_2\Tamil_master\Tamil_master\Tamil - Copy',
    ]
    speaker_info_file = r'C:\Users\deeps\VSCodeProjects\Jio_internship_project_2\total_spkrinfo.list'
    speaker_dict = get_speaker_info(speaker_info_file)

    csv_file_number = 1
    record_count = 0
    max_records_per_file = 2000000

    csv_file = f'audio_features{csv_file_number}.csv'
    f = open(csv_file, 'a', newline='')
    writer = csv.writer(f)
    write_header(writer)

    for source_dir in source_dirs:
        for root, _, files in os.walk(source_dir):
            for file in files:
                if file.endswith('.wav'):
                    audio_file = os.path.join(root, file)
                    speaker_id = file[:8]
                    output_label = speaker_dict.get(speaker_id, [0] * 5)
                    audio, sr = librosa.load(audio_file, sr=None)
                    features = extract_features(audio, sr, output_label)
                    for frame_features in features:
                        writer.writerow(frame_features[0].tolist() + [frame_features[1][0]] + frame_features[1][1:])
                        record_count += 1

                        if record_count >= max_records_per_file:
                            f.close()
                            csv_file_number += 1
                            csv_file = f'audio_features{csv_file_number}.csv'
                            f = open(csv_file, 'a', newline='')
                            writer = csv.writer(f)
                            write_header(writer)
                            record_count = 0

                    print(f'Processed {file} - {record_count} records in current file')

    f.close()
    print("Feature extraction and CSV writing completed")

if __name__ == '__main__':
    process_audio_files()
# Out:
# c:\Users\deeps\anaconda3\Lib\site-packages\numpy\core\_methods.py:215: RuntimeWarning: overflow encountered in reduce
#   arrmean = umr_sum(arr, axis, dtype, keepdims=True, where=where)
# c:\Users\deeps\anaconda3\Lib\site-packages\numpy\core\_methods.py:250: RuntimeWarning: overflow encountered in reduce
#   ret = umr_sum(x, axis, dtype, out, keepdims=keepdims, where=where)
# c:\Users\deeps\anaconda3\Lib\site-packages\scipy\stats\_stats_py.py:1094: RuntimeWarning: overflow encountered in multiply
#   s *= a_zero_mean
# c:\Users\deeps\anaconda3\Lib\site-packages\numpy\core\_methods.py:181: RuntimeWarning: invalid value encountered in reduce
#   ret = umr_sum(arr, axis, dtype, out, keepdims, where=where)
# c:\Users\deeps\anaconda3\Lib\site-packages\scipy\stats\_stats_py.py:1092: RuntimeWarning: overflow encountered in square
#   s = s**2
# Processed Tam_0001_Eng_m_0000.wav - 666 records in current file
# Processed Tam_0001_Eng_m_0001.wav - 1323 records in current file
# Processed Tam_0001_Eng_m_0002.wav - 2330 records in current file
# Processed Tam_0001_Eng_m_0003.wav - 3759 records in current file
# Processed Tam_0001_Eng_m_0004.wav - 4538 records in current file
# Processed Tam_0001_Eng_m_0005.wav - 5317 records in current file
# Processed Tam_0001_Eng_m_8081.wav - 7264 records in current file
# Processed Tam_0001_Eng_m_8082.wav - 9818 records in current file
# Processed Tam_0001_Eng_m_8083.wav - 10709 records in current file
# Processed Tam_0001_Eng_m_8084.wav - 12300 records in current file
# Processed Tam_0001_Eng_m_8085.wav - 13688 records in current file
# Processed Tam_0001_Eng_m_8086.wav - 15829 records in current file
# c:\Users\deeps\anaconda3\Lib\site-packages\scipy\stats\_stats_py.py:1088: RuntimeWarning: overflow encountered in square
#   s = a_zero_mean**2
# Processed Tam_0001_Eng_m_8087.wav - 16289 records in current file
# Processed Tam_0001_Eng_m_8088.wav - 18305 records in current file
# Processed Tam_0001_Eng_m_8089.wav - 20349 records in current file
# Processed Tam_0001_Eng_m_8090.wav - 23050 records in current file
# Processed Tam_0001_Eng_m_8091.wav - 24860 records in current file
# Processed Tam_0001_Eng_m_8092.wav - 26689 records in current file
# Processed Tam_0001_Eng_m_8093.wav - 29527 records in current file
# Processed Tam_0001_Eng_m_8094.wav - 31527 records in current file
# Processed Tam_0001_Eng_m_8095.wav - 33584 records in current file
# Processed Tam_0001_Eng_m_8096.wav - 35431 records in current file
# Processed Tam_0001_Eng_m_8097.wav - 36210 records in current file
# Processed Tam_0001_Eng_m_8098.wav - 37954 records in current file
# Processed Tam_0001_Eng_m_8099.wav - 39229 records in current file
# Processed Tam_0001_Eng_m_8100.wav - 42020 records in current file
# Processed Tam_0001_Eng_m_8101.wav - 43233 records in current file
# Processed Tam_0001_Eng_m_8102.wav - 44971 records in current file
# Processed Tam_0001_Eng_m_8103.wav - 46068 records in current file
# Processed Tam_0001_Eng_m_8104.wav - 47765 records in current file
# Processed Tam_0001_Eng_m_8105.wav - 48903 records in current file
# Processed Tam_0001_Eng_m_8106.wav - 49450 records in current file
# Processed Tam_0001_Eng_m_8107.wav - 50163 records in current file
# Processed Tam_0001_Eng_m_8108.wav - 51407 records in current file
# Processed Tam_0001_Eng_m_8109.wav - 53089 records in current file
# Processed Tam_0001_Eng_m_8110.wav - 53983 records in current file
# Processed Tam_0001_Eng_m_8111.wav - 54615 records in current file
# Processed Tam_0001_Eng_m_8112.wav - 55894 records in current file
# Processed Tam_0001_Eng_m_8113.wav - 57229 records in current file
# Processed Tam_0001_Eng_m_8114.wav - 57883 records in current file
# Processed Tam_0001_Eng_m_8115.wav - 58387 records in current file
# Processed Tam_0001_Eng_m_8116.wav - 60341 records in current file
# Processed Tam_0001_Eng_m_8117.wav - 61048 records in current file
# Processed Tam_0002_Eng_m_0000.wav - 61652 records in current file
# Processed Tam_0002_Eng_m_0001.wav - 62215 records in current file
# Processed Tam_0002_Eng_m_0002.wav - 63203 records in current file
# Processed Tam_0002_Eng_m_0003.wav - 64479 records in current file
# Processed Tam_0002_Eng_m_0004.wav - 65145 records in current file
# Processed Tam_0002_Eng_m_0005.wav - 65833 records in current file
# Processed Tam_0002_Eng_m_8118.wav - 67774 records in current file
# Processed Tam_0002_Eng_m_8119.wav - 69781 records in current file
# Processed Tam_0002_Eng_m_8120.wav - 70591 records in current file
# Processed Tam_0002_Eng_m_8121.wav - 71629 records in current file
# Processed Tam_0002_Eng_m_8122.wav - 72892 records in current file
# Processed Tam_0002_Eng_m_8123.wav - 73702 records in current file
# Processed Tam_0002_Eng_m_8124.wav - 74940 records in current file
# Processed Tam_0002_Eng_m_8125.wav - 76450 records in current file
# Processed Tam_0002_Eng_m_8126.wav - 78185 records in current file
# Processed Tam_0002_Eng_m_8127.wav - 79261 records in current file
# Processed Tam_0002_Eng_m_8128.wav - 81571 records in current file
# Processed Tam_0002_Eng_m_8129.wav - 83206 records in current file
# Processed Tam_0002_Eng_m_8130.wav - 85785 records in current file
# Processed Tam_0002_Eng_m_8131.wav - 88064 records in current file
# Processed Tam_0002_Eng_m_8132.wav - 89383 records in current file
# Processed Tam_0002_Eng_m_8133.wav - 90587 records in current file
# Processed Tam_0002_Eng_m_8134.wav - 92091 records in current file
# Processed Tam_0002_Eng_m_8135.wav - 93554 records in current file
# Processed Tam_0002_Eng_m_8136.wav - 94776 records in current file
# Processed Tam_0002_Eng_m_8137.wav - 95520 records in current file
# Processed Tam_0002_Eng_m_8138.wav - 96439 records in current file
# Processed Tam_0002_Eng_m_8139.wav - 97990 records in current file
# Processed Tam_0002_Eng_m_8140.wav - 99250 records in current file
# Processed Tam_0002_Eng_m_8141.wav - 100875 records in current file
# Processed Tam_0002_Eng_m_8142.wav - 101954 records in current file
# Processed Tam_0002_Eng_m_8143.wav - 102736 records in current file
# Processed Tam_0002_Eng_m_8144.wav - 103349 records in current file
# Processed Tam_0002_Eng_m_8145.wav - 104171 records in current file
# Processed Tam_0002_Eng_m_8146.wav - 104790 records in current file
# Processed Tam_0002_Eng_m_8147.wav - 105219 records in current file
# Processed Tam_0002_Eng_m_8148.wav - 106110 records in current file
# Processed Tam_0002_Eng_m_8149.wav - 107017 records in current file
# Processed Tam_0004_Eng_m_0000.wav - 107599 records in current file
# Processed Tam_0004_Eng_m_0001.wav - 108153 records in current file
# Processed Tam_0004_Eng_m_0002.wav - 108910 records in current file
# Processed Tam_0004_Eng_m_0003.wav - 109967 records in current file
# Processed Tam_0004_Eng_m_0004.wav - 110671 records in current file
# Processed Tam_0004_Eng_m_0005.wav - 111240 records in current file
# Processed Tam_0004_Eng_m_8186.wav - 112409 records in current file
# Processed Tam_0004_Eng_m_8187.wav - 113069 records in current file
# Processed Tam_0004_Eng_m_8188.wav - 114226 records in current file
# Processed Tam_0004_Eng_m_8189.wav - 115333 records in current file
# Processed Tam_0004_Eng_m_8190.wav - 116218 records in current file
# Processed Tam_0004_Eng_m_8191.wav - 117678 records in current file
# Processed Tam_0004_Eng_m_8192.wav - 118910 records in current file
# Processed Tam_0004_Eng_m_8193.wav - 120898 records in current file
# Processed Tam_0004_Eng_m_8194.wav - 121930 records in current file
# Processed Tam_0004_Eng_m_8195.wav - 122730 records in current file
# Processed Tam_0004_Eng_m_8196.wav - 123759 records in current file
# Processed Tam_0004_Eng_m_8197.wav - 125397 records in current file
# Processed Tam_0004_Eng_m_8198.wav - 126547 records in current file
# Processed Tam_0004_Eng_m_8199.wav - 127679 records in current file
# Processed Tam_0004_Eng_m_8200.wav - 128198 records in current file
# Processed Tam_0004_Eng_m_8201.wav - 128930 records in current file
# Processed Tam_0004_Eng_m_8202.wav - 129849 records in current file
# Processed Tam_0004_Eng_m_8203.wav - 130703 records in current file
# Processed Tam_0004_Eng_m_8204.wav - 132260 records in current file
# Processed Tam_0004_Eng_m_8205.wav - 133198 records in current file
# Processed Tam_0004_Eng_m_8206.wav - 134549 records in current file
# Processed Tam_0004_Eng_m_8207.wav - 135165 records in current file
# Processed Tam_0004_Eng_m_8208.wav - 136294 records in current file
# Processed Tam_0004_Eng_m_8209.wav - 137885 records in current file
# Processed Tam_0004_Eng_m_8210.wav - 138964 records in current file
# Processed Tam_0004_Eng_m_8211.wav - 140052 records in current file
# Processed Tam_0004_Eng_m_8212.wav - 140746 records in current file
# Processed Tam_0004_Eng_m_8213.wav - 141234 records in current file
# Processed Tam_0004_Eng_m_8214.wav - 141959 records in current file
# Processed Tam_0004_Eng_m_8215.wav - 142756 records in current file
# Processed Tam_0004_Eng_m_8216.wav - 143341 records in current file
# Processed Tam_0004_Eng_m_8217.wav - 143813 records in current file
# Processed Tam_0004_Eng_m_8218.wav - 144585 records in current file
# Processed Tam_0004_Eng_m_8219.wav - 145320 records in current file
# Processed Tam_0004_Eng_m_8220.wav - 145692 records in current file
# Processed Tam_0004_Eng_m_8221.wav - 147017 records in current file
# Processed Tam_0004_Eng_m_8222.wav - 147796 records in current file
# Processed Tam_0005_Eng_m_0000.wav - 148481 records in current file
# Processed Tam_0005_Eng_m_0001.wav - 149085 records in current file
# Processed Tam_0005_Eng_m_0002.wav - 149923 records in current file
# Processed Tam_0005_Eng_m_0003.wav - 151217 records in current file
# Processed Tam_0005_Eng_m_0004.wav - 151961 records in current file
# Processed Tam_0005_Eng_m_0005.wav - 152583 records in current file
# Processed Tam_0005_Eng_m_8223.wav - 153405 records in current file
# Processed Tam_0005_Eng_m_8224.wav - 154556 records in current file
# Processed Tam_0005_Eng_m_8225.wav - 155482 records in current file
# Processed Tam_0005_Eng_m_8226.wav - 156129 records in current file
# Processed Tam_0005_Eng_m_8227.wav - 158179 records in current file
# Processed Tam_0005_Eng_m_8228.wav - 160036 records in current file
# Processed Tam_0005_Eng_m_8229.wav - 160521 records in current file
# Processed Tam_0005_Eng_m_8230.wav - 161650 records in current file
# Processed Tam_0005_Eng_m_8231.wav - 163441 records in current file
# Processed Tam_0005_Eng_m_8232.wav - 165066 records in current file
# Processed Tam_0005_Eng_m_8233.wav - 165554 records in current file
# Processed Tam_0005_Eng_m_8234.wav - 166751 records in current file
# Processed Tam_0005_Eng_m_8235.wav - 167601 records in current file
# Processed Tam_0005_Eng_m_8236.wav - 168817 records in current file
# Processed Tam_0005_Eng_m_8237.wav - 169755 records in current file
# Processed Tam_0005_Eng_m_8238.wav - 171718 records in current file
# Processed Tam_0005_Eng_m_8239.wav - 172612 records in current file
# Processed Tam_0005_Eng_m_8240.wav - 174128 records in current file
# Processed Tam_0005_Eng_m_8241.wav - 175457 records in current file
# Processed Tam_0005_Eng_m_8242.wav - 177233 records in current file
# Processed Tam_0005_Eng_m_8243.wav - 178555 records in current file
# Processed Tam_0005_Eng_m_8244.wav - 179890 records in current file
# Processed Tam_0005_Eng_m_8245.wav - 181659 records in current file
# Processed Tam_0005_Eng_m_8246.wav - 182038 records in current file
# Processed Tam_0005_Eng_m_8247.wav - 183442 records in current file
# Processed Tam_0005_Eng_m_8248.wav - 184896 records in current file
# Processed Tam_0005_Eng_m_8249.wav - 185540 records in current file
# Processed Tam_0005_Eng_m_8250.wav - 186925 records in current file
# Processed Tam_0005_Eng_m_8251.wav - 187554 records in current file
# Processed Tam_0005_Eng_m_8252.wav - 188754 records in current file
# Processed Tam_0005_Eng_m_8253.wav - 190561 records in current file
# Processed Tam_0005_Eng_m_8254.wav - 191218 records in current file
# Processed Tam_0005_Eng_m_8255.wav - 191987 records in current file
# Processed Tam_0006_Eng_m_0000.wav - 192766 records in current file
# Processed Tam_0006_Eng_m_0001.wav - 193504 records in current file
# c:\Users\deeps\anaconda3\Lib\site-packages\scipy\stats\_stats_py.py:1074: RuntimeWarning: overflow encountered in divide
#   rel_diff = np.max(np.abs(a_zero_mean), axis=axis,
# Processed Tam_0006_Eng_m_0002.wav - 194329 records in current file
# Processed Tam_0006_Eng_m_0003.wav - 195483 records in current file
# Processed Tam_0006_Eng_m_0004.wav - 196159 records in current file
# Processed Tam_0006_Eng_m_0005.wav - 196800 records in current file
# Processed Tam_0006_Eng_m_8256.wav - 198116 records in current file
# Processed Tam_0006_Eng_m_8257.wav - 199632 records in current file
# Processed Tam_0006_Eng_m_8258.wav - 201089 records in current file
# Processed Tam_0006_Eng_m_8259.wav - 202361 records in current file
# Processed Tam_0006_Eng_m_8260.wav - 204633 records in current file
# Processed Tam_0006_Eng_m_8261.wav - 205549 records in current file
# Processed Tam_0006_Eng_m_8262.wav - 206681 records in current file
# Processed Tam_0006_Eng_m_8263.wav - 208778 records in current file
# Processed Tam_0006_Eng_m_8264.wav - 210010 records in current file
# Processed Tam_0006_Eng_m_8265.wav - 210807 records in current file
# Processed Tam_0006_Eng_m_8266.wav - 212604 records in current file
# Processed Tam_0006_Eng_m_8267.wav - 214098 records in current file
# Processed Tam_0006_Eng_m_8268.wav - 215149 records in current file
# Processed Tam_0006_Eng_m_8269.wav - 215678 records in current file
# Processed Tam_0006_Eng_m_8270.wav - 216697 records in current file
# Processed Tam_0006_Eng_m_8271.wav - 217616 records in current file
# Processed Tam_0006_Eng_m_8272.wav - 219266 records in current file
# Processed Tam_0006_Eng_m_8273.wav - 221466 records in current file
# Processed Tam_0006_Eng_m_8274.wav - 222554 records in current file
# Processed Tam_0006_Eng_m_8275.wav - 223848 records in current file
# Processed Tam_0006_Eng_m_8276.wav - 224833 records in current file
# Processed Tam_0006_Eng_m_8277.wav - 226680 records in current file
# Processed Tam_0006_Eng_m_8278.wav - 229093 records in current file
# Processed Tam_0006_Eng_m_8279.wav - 230753 records in current file
# Processed Tam_0006_Eng_m_8280.wav - 232266 records in current file
# Processed Tam_0006_Eng_m_8281.wav - 233066 records in current file
# Processed Tam_0006_Eng_m_8282.wav - 233901 records in current file
# Processed Tam_0006_Eng_m_8283.wav - 234876 records in current file
# Processed Tam_0006_Eng_m_8284.wav - 235914 records in current file
# Processed Tam_0006_Eng_m_8285.wav - 236602 records in current file
# Processed Tam_0006_Eng_m_8286.wav - 237512 records in current file
# Processed Tam_0006_Eng_m_8287.wav - 238172 records in current file
# Processed Tam_0006_Eng_m_8288.wav - 239004 records in current file
# Processed Tam_0007_Eng_f_0000.wav - 239636 records in current file
# Processed Tam_0007_Eng_f_0001.wav - 240221 records in current file
# Processed Tam_0007_Eng_f_0002.wav - 240947 records in current file
# Processed Tam_0007_Eng_f_0003.wav - 242176 records in current file
# Processed Tam_0007_Eng_f_0004.wav - 242905 records in current file
# Processed Tam_0007_Eng_f_0005.wav - 243484 records in current file
# Processed Tam_0007_Eng_f_8289.wav - 245138 records in current file
# Processed Tam_0007_Eng_f_8290.wav - 246529 records in current file
# Processed Tam_0007_Eng_f_8291.wav - 247551 records in current file
# Processed Tam_0007_Eng_f_8292.wav - 248417 records in current file
# Processed Tam_0007_Eng_f_8293.wav - 250743 records in current file
# Processed Tam_0007_Eng_f_8294.wav - 251425 records in current file
# Processed Tam_0007_Eng_f_8295.wav - 252629 records in current file
# Processed Tam_0007_Eng_f_8296.wav - 253876 records in current file
# Processed Tam_0007_Eng_f_8297.wav - 255083 records in current file
# Processed Tam_0007_Eng_f_8298.wav - 256124 records in current file
# Processed Tam_0007_Eng_f_8299.wav - 256943 records in current file
# Processed Tam_0007_Eng_f_8300.wav - 258300 records in current file
# Processed Tam_0007_Eng_f_8301.wav - 259213 records in current file
# Processed Tam_0007_Eng_f_8302.wav - 259832 records in current file
# Processed Tam_0007_Eng_f_8303.wav - 260695 records in current file
# Processed Tam_0007_Eng_f_8304.wav - 262642 records in current file
# Processed Tam_0007_Eng_f_8305.wav - 264211 records in current file
# Processed Tam_0007_Eng_f_8306.wav - 264837 records in current file
# Processed Tam_0007_Eng_f_8307.wav - 265859 records in current file
# Processed Tam_0007_Eng_f_8308.wav - 266788 records in current file
# Processed Tam_0007_Eng_f_8309.wav - 268426 records in current file
# Processed Tam_0007_Eng_f_8310.wav - 269248 records in current file
# Processed Tam_0007_Eng_f_8311.wav - 270455 records in current file
# Processed Tam_0007_Eng_f_8312.wav - 271749 records in current file
# Processed Tam_0007_Eng_f_8313.wav - 272412 records in current file
# Processed Tam_0007_Eng_f_8314.wav - 273284 records in current file
# Processed Tam_0007_Eng_f_8315.wav - 273969 records in current file
# Processed Tam_0007_Eng_f_8316.wav - 274788 records in current file
# Processed Tam_0007_Eng_f_8317.wav - 275401 records in current file
# Processed Tam_0007_Eng_f_8318.wav - 276983 records in current file
# Processed Tam_0007_Eng_f_8319.wav - 277724 records in current file
# Processed Tam_0007_Eng_f_8320.wav - 278706 records in current file
# Processed Tam_0007_Eng_f_8321.wav - 279288 records in current file
# Processed Tam_0008_Eng_m_0000.wav - 279957 records in current file
# Processed Tam_0008_Eng_m_0001.wav - 280536 records in current file
# Processed Tam_0008_Eng_m_0002.wav - 281249 records in current file
# Processed Tam_0008_Eng_m_0003.wav - 282331 records in current file
# Processed Tam_0008_Eng_m_0004.wav - 282978 records in current file
# Processed Tam_0008_Eng_m_0005.wav - 283544 records in current file
# Processed Tam_0008_Eng_m_8322.wav - 284460 records in current file
# Processed Tam_0008_Eng_m_8323.wav - 285317 records in current file
# Processed Tam_0008_Eng_m_8324.wav - 286508 records in current file
# Processed Tam_0008_Eng_m_8325.wav - 288171 records in current file
# Processed Tam_0008_Eng_m_8326.wav - 289181 records in current file
# Processed Tam_0008_Eng_m_8327.wav - 290957 records in current file
# Processed Tam_0008_Eng_m_8328.wav - 292145 records in current file
# Processed Tam_0008_Eng_m_8329.wav - 292974 records in current file
# Processed Tam_0008_Eng_m_8330.wav - 294681 records in current file
# Processed Tam_0008_Eng_m_8331.wav - 296035 records in current file
# Processed Tam_0008_Eng_m_8332.wav - 297107 records in current file
# Processed Tam_0008_Eng_m_8333.wav - 299004 records in current file
# Processed Tam_0008_Eng_m_8334.wav - 300304 records in current file
# Processed Tam_0008_Eng_m_8335.wav - 301770 records in current file
# Processed Tam_0008_Eng_m_8336.wav - 303242 records in current file
# Processed Tam_0008_Eng_m_8337.wav - 304474 records in current file
# Processed Tam_0008_Eng_m_8338.wav - 306093 records in current file
# Processed Tam_0008_Eng_m_8339.wav - 307590 records in current file
# Processed Tam_0008_Eng_m_8340.wav - 309128 records in current file
# Processed Tam_0008_Eng_m_8341.wav - 310316 records in current file
# Processed Tam_0008_Eng_m_8342.wav - 311492 records in current file
# Processed Tam_0008_Eng_m_8343.wav - 313508 records in current file
# Processed Tam_0008_Eng_m_8344.wav - 315190 records in current file
# Processed Tam_0008_Eng_m_8345.wav - 316206 records in current file
# Processed Tam_0008_Eng_m_8346.wav - 316982 records in current file
# Processed Tam_0008_Eng_m_8347.wav - 318204 records in current file
# Processed Tam_0008_Eng_m_8348.wav - 319245 records in current file
# Processed Tam_0008_Eng_m_8349.wav - 320302 records in current file
# Processed Tam_0008_Eng_m_8350.wav - 321821 records in current file
# Processed Tam_0008_Eng_m_8351.wav - 322925 records in current file
# Processed Tam_0008_Eng_m_8352.wav - 323835 records in current file
# Processed Tam_0008_Eng_m_8353.wav - 324457 records in current file
# Processed Tam_0008_Eng_m_8354.wav - 325189 records in current file
# Processed Tam_0008_Eng_m_8355.wav - 325799 records in current file
# Processed Tam_0008_Eng_m_8356.wav - 326675 records in current file
# Processed Tam_0008_Eng_m_8357.wav - 327719 records in current file
# Processed Tam_0008_Eng_m_8358.wav - 328579 records in current file
# Processed Tam_0008_Eng_m_8359.wav - 329164 records in current file
# Processed Tam_0008_Eng_m_8360.wav - 331293 records in current file
# Processed Tam_0008_Eng_m_8361.wav - 332612 records in current file
# Processed Tam_0008_Eng_m_8362.wav - 333703 records in current file
# Processed Tam_0008_Eng_m_8363.wav - 334272 records in current file
# Processed Tam_0008_Eng_m_8364.wav - 335097 records in current file
# Processed Tam_0008_Eng_m_8365.wav - 336357 records in current file
# Processed Tam_0008_Eng_m_8366.wav - 337217 records in current file
# Processed Tam_0012_Eng_m_0000.wav - 337821 records in current file
# Processed Tam_0012_Eng_m_0001.wav - 338425 records in current file
# Processed Tam_0012_Eng_m_0002.wav - 339254 records in current file
# Processed Tam_0012_Eng_m_0003.wav - 340520 records in current file
# Processed Tam_0012_Eng_m_0004.wav - 341074 records in current file
# Processed Tam_0012_Eng_m_0005.wav - 341653 records in current file
# Processed Tam_0012_Eng_m_8466.wav - 342794 records in current file
# Processed Tam_0012_Eng_m_8467.wav - 343285 records in current file
# Processed Tam_0012_Eng_m_8468.wav - 343970 records in current file
# Processed Tam_0012_Eng_m_8469.wav - 344892 records in current file
# Processed Tam_0012_Eng_m_8470.wav - 345624 records in current file
# Processed Tam_0012_Eng_m_8471.wav - 347184 records in current file
# Processed Tam_0012_Eng_m_8472.wav - 348950 records in current file
# Processed Tam_0012_Eng_m_8473.wav - 350066 records in current file
# Processed Tam_0012_Eng_m_8474.wav - 351263 records in current file
# Processed Tam_0012_Eng_m_8475.wav - 352317 records in current file
# Processed Tam_0012_Eng_m_8476.wav - 352911 records in current file
# Processed Tam_0012_Eng_m_8477.wav - 354412 records in current file
# Processed Tam_0012_Eng_m_8478.wav - 355322 records in current file
# Processed Tam_0012_Eng_m_8479.wav - 356219 records in current file
# Processed Tam_0012_Eng_m_8480.wav - 357210 records in current file
# Processed Tam_0012_Eng_m_8481.wav - 358217 records in current file
# Processed Tam_0012_Eng_m_8482.wav - 359408 records in current file
# Processed Tam_0012_Eng_m_8483.wav - 360365 records in current file
# Processed Tam_0012_Eng_m_8484.wav - 361172 records in current file
# Processed Tam_0012_Eng_m_8485.wav - 361848 records in current file
# Processed Tam_0012_Eng_m_8486.wav - 363264 records in current file
# Processed Tam_0012_Eng_m_8487.wav - 364108 records in current file
# Processed Tam_0012_Eng_m_8488.wav - 364821 records in current file
# Processed Tam_0012_Eng_m_8489.wav - 366247 records in current file
# Processed Tam_0012_Eng_m_8490.wav - 368269 records in current file
# Processed Tam_0012_Eng_m_8491.wav - 369107 records in current file
# Processed Tam_0012_Eng_m_8492.wav - 370029 records in current file
# Processed Tam_0012_Eng_m_8493.wav - 371261 records in current file
# Processed Tam_0012_Eng_m_8494.wav - 372690 records in current file
# Processed Tam_0012_Eng_m_8495.wav - 374175 records in current file
# Processed Tam_0012_Eng_m_8496.wav - 374866 records in current file
# Processed Tam_0013_Eng_f_0000.wav - 375423 records in current file
# Processed Tam_0013_Eng_f_0001.wav - 376049 records in current file
# Processed Tam_0013_Eng_f_0002.wav - 376771 records in current file
# Processed Tam_0013_Eng_f_0003.wav - 377890 records in current file
# Processed Tam_0013_Eng_f_0004.wav - 378550 records in current file
# Processed Tam_0013_Eng_f_0005.wav - 379154 records in current file
# Processed Tam_0013_Eng_f_8497.wav - 380330 records in current file
# Processed Tam_0013_Eng_f_8498.wav - 382074 records in current file
# Processed Tam_0013_Eng_f_8499.wav - 383731 records in current file
# Processed Tam_0013_Eng_f_8500.wav - 384763 records in current file
# Processed Tam_0013_Eng_f_8501.wav - 385954 records in current file
# Processed Tam_0013_Eng_f_8502.wav - 387089 records in current file
# Processed Tam_0013_Eng_f_8503.wav - 388939 records in current file
# Processed Tam_0013_Eng_f_8504.wav - 390480 records in current file
# Processed Tam_0013_Eng_f_8505.wav - 391777 records in current file
# Processed Tam_0013_Eng_f_8506.wav - 393424 records in current file
# Processed Tam_0013_Eng_f_8507.wav - 394728 records in current file
# Processed Tam_0013_Eng_f_8508.wav - 395854 records in current file
# Processed Tam_0013_Eng_f_8509.wav - 397242 records in current file
# Processed Tam_0013_Eng_f_8510.wav - 398736 records in current file
# Processed Tam_0013_Eng_f_8511.wav - 399940 records in current file
# Processed Tam_0013_Eng_f_8512.wav - 401209 records in current file
# Processed Tam_0013_Eng_f_8513.wav - 402038 records in current file
# Processed Tam_0013_Eng_f_8514.wav - 402942 records in current file
# Processed Tam_0013_Eng_f_8515.wav - 403927 records in current file
# Processed Tam_0013_Eng_f_8516.wav - 405221 records in current file
# Processed Tam_0013_Eng_f_8517.wav - 406215 records in current file
# Processed Tam_0013_Eng_f_8518.wav - 407372 records in current file
# Processed Tam_0013_Eng_f_8519.wav - 408094 records in current file
# Processed Tam_0013_Eng_f_8520.wav - 409604 records in current file
# Processed Tam_0013_Eng_f_8521.wav - 410708 records in current file
# Processed Tam_0013_Eng_f_8522.wav - 411552 records in current file
# Processed Tam_0013_Eng_f_8523.wav - 412399 records in current file
# Processed Tam_0013_Eng_f_8524.wav - 413112 records in current file
# Processed Tam_0013_Eng_f_8525.wav - 413712 records in current file
# Processed Tam_0013_Eng_f_8526.wav - 414897 records in current file
# Processed Tam_0013_Eng_f_8527.wav - 415607 records in current file
# Processed Tam_0013_Eng_f_8528.wav - 416517 records in current file
# Processed Tam_0013_Eng_f_8529.wav - 417871 records in current file
# Processed Tam_0014_Eng_m_0000.wav - 418406 records in current file
# Processed Tam_0014_Eng_m_0001.wav - 419007 records in current file
# Processed Tam_0014_Eng_m_0002.wav - 419829 records in current file
# Processed Tam_0014_Eng_m_0003.wav - 421058 records in current file
# Processed Tam_0014_Eng_m_0004.wav - 421774 records in current file
# Processed Tam_0014_Eng_m_0005.wav - 422418 records in current file
# Processed Tam_0014_Eng_m_8530.wav - 424309 records in current file
# Processed Tam_0014_Eng_m_8531.wav - 426547 records in current file
# Processed Tam_0014_Eng_m_8532.wav - 428319 records in current file
# Processed Tam_0014_Eng_m_8533.wav - 430504 records in current file
# Processed Tam_0014_Eng_m_8534.wav - 433770 records in current file
# Processed Tam_0014_Eng_m_8535.wav - 436230 records in current file
# Processed Tam_0014_Eng_m_8536.wav - 437765 records in current file
# Processed Tam_0014_Eng_m_8537.wav - 439059 records in current file
# Processed Tam_0014_Eng_m_8538.wav - 439991 records in current file
# Processed Tam_0014_Eng_m_8539.wav - 442129 records in current file
# Processed Tam_0014_Eng_m_8540.wav - 444148 records in current file
# Processed Tam_0014_Eng_m_8541.wav - 445992 records in current file
# Processed Tam_0014_Eng_m_8542.wav - 446749 records in current file
# Processed Tam_0014_Eng_m_8543.wav - 448890 records in current file
# Processed Tam_0014_Eng_m_8544.wav - 449690 records in current file
# Processed Tam_0014_Eng_m_8545.wav - 450878 records in current file
# Processed Tam_0014_Eng_m_8546.wav - 451854 records in current file
# Processed Tam_0014_Eng_m_8547.wav - 454533 records in current file
# Processed Tam_0014_Eng_m_8548.wav - 455249 records in current file
# Processed Tam_0014_Eng_m_8549.wav - 456940 records in current file
# Processed Tam_0014_Eng_m_8550.wav - 458194 records in current file
# Processed Tam_0014_Eng_m_8551.wav - 459929 records in current file
# Processed Tam_0014_Eng_m_8552.wav - 461055 records in current file
# Processed Tam_0014_Eng_m_8553.wav - 461649 records in current file
# Processed Tam_0014_Eng_m_8554.wav - 464087 records in current file
# Processed Tam_0014_Eng_m_8555.wav - 465478 records in current file
# Processed Tam_0014_Eng_m_8556.wav - 466494 records in current file
# Processed Tam_0014_Eng_m_8557.wav - 468663 records in current file
# Processed Tam_0014_Eng_m_8558.wav - 469629 records in current file
# Processed Tam_0014_Eng_m_8559.wav - 471383 records in current file
# Processed Tam_0014_Eng_m_8560.wav - 472915 records in current file
# Processed Tam_0016_Eng_m_0000.wav - 473428 records in current file
# Processed Tam_0016_Eng_m_0001.wav - 473988 records in current file
# Processed Tam_0016_Eng_m_0002.wav - 474645 records in current file
# Processed Tam_0016_Eng_m_0003.wav - 475696 records in current file
# Processed Tam_0016_Eng_m_0004.wav - 476268 records in current file
# Processed Tam_0016_Eng_m_0005.wav - 476762 records in current file
# Processed Tam_0016_Eng_m_8591.wav - 478156 records in current file
# Processed Tam_0016_Eng_m_8592.wav - 479110 records in current file
# Processed Tam_0016_Eng_m_8593.wav - 480639 records in current file
# Processed Tam_0016_Eng_m_8594.wav - 481727 records in current file
# Processed Tam_0016_Eng_m_8595.wav - 483343 records in current file
# Processed Tam_0016_Eng_m_8596.wav - 484440 records in current file
# Processed Tam_0016_Eng_m_8597.wav - 485081 records in current file
# Processed Tam_0016_Eng_m_8598.wav - 486182 records in current file
# Processed Tam_0016_Eng_m_8599.wav - 487629 records in current file
# Processed Tam_0016_Eng_m_8600.wav - 488708 records in current file
# Processed Tam_0016_Eng_m_8601.wav - 489633 records in current file
# Processed Tam_0016_Eng_m_8602.wav - 491105 records in current file
# Processed Tam_0016_Eng_m_8603.wav - 491893 records in current file
# Processed Tam_0016_Eng_m_8604.wav - 493122 records in current file
# Processed Tam_0016_Eng_m_8605.wav - 494160 records in current file
# Processed Tam_0016_Eng_m_8606.wav - 495329 records in current file
# Processed Tam_0016_Eng_m_8607.wav - 496745 records in current file
# Processed Tam_0016_Eng_m_8608.wav - 497733 records in current file
# Processed Tam_0016_Eng_m_8609.wav - 498365 records in current file
# Processed Tam_0016_Eng_m_8610.wav - 499565 records in current file
# Processed Tam_0016_Eng_m_8611.wav - 500906 records in current file
# Processed Tam_0016_Eng_m_8612.wav - 501938 records in current file
# Processed Tam_0016_Eng_m_8613.wav - 502814 records in current file
# Processed Tam_0016_Eng_m_8614.wav - 503833 records in current file
# Processed Tam_0016_Eng_m_8615.wav - 504702 records in current file
# Processed Tam_0016_Eng_m_8616.wav - 505565 records in current file
# Processed Tam_0016_Eng_m_8617.wav - 506928 records in current file
# Processed Tam_0016_Eng_m_8618.wav - 507466 records in current file
# Processed Tam_0016_Eng_m_8619.wav - 507916 records in current file
# Processed Tam_0016_Eng_m_8620.wav - 508641 records in current file
# Processed Tam_0016_Eng_m_8621.wav - 509398 records in current file
# Processed Tam_0016_Eng_m_8622.wav - 510127 records in current file
# Processed Tam_0016_Eng_m_8623.wav - 510674 records in current file
# Processed Tam_0016_Eng_m_8624.wav - 511425 records in current file
# Processed Tam_0016_Eng_m_8625.wav - 512032 records in current file
# Processed Tam_0018_Eng_m_0000.wav - 512611 records in current file
# Processed Tam_0018_Eng_m_0001.wav - 513140 records in current file
# Processed Tam_0018_Eng_m_0002.wav - 514040 records in current file
# Processed Tam_0018_Eng_m_0003.wav - 515366 records in current file
# Processed Tam_0018_Eng_m_0004.wav - 516148 records in current file
# Processed Tam_0018_Eng_m_0005.wav - 516786 records in current file
# Processed Tam_0018_Eng_m_8662.wav - 517599 records in current file
# Processed Tam_0018_Eng_m_8663.wav - 518846 records in current file
# Processed Tam_0018_Eng_m_8664.wav - 519650 records in current file
# Processed Tam_0018_Eng_m_8665.wav - 520726 records in current file
# Processed Tam_0018_Eng_m_8666.wav - 521789 records in current file
# Processed Tam_0018_Eng_m_8667.wav - 522777 records in current file
# Processed Tam_0018_Eng_m_8668.wav - 523246 records in current file
# Processed Tam_0018_Eng_m_8669.wav - 523809 records in current file
# Processed Tam_0018_Eng_m_8670.wav - 525353 records in current file
# Processed Tam_0018_Eng_m_8671.wav - 526357 records in current file
# Processed Tam_0018_Eng_m_8672.wav - 528829 records in current file
# Processed Tam_0018_Eng_m_8673.wav - 530514 records in current file
# Processed Tam_0018_Eng_m_8674.wav - 532058 records in current file
# Processed Tam_0018_Eng_m_8675.wav - 532968 records in current file
# Processed Tam_0018_Eng_m_8676.wav - 534731 records in current file
# Processed Tam_0018_Eng_m_8677.wav - 536691 records in current file
# Processed Tam_0018_Eng_m_8678.wav - 538260 records in current file
# Processed Tam_0018_Eng_m_8679.wav - 541032 records in current file
# Processed Tam_0018_Eng_m_8680.wav - 542282 records in current file
# Processed Tam_0018_Eng_m_8681.wav - 544482 records in current file
# Processed Tam_0018_Eng_m_8682.wav - 545698 records in current file
# Processed Tam_0018_Eng_m_8683.wav - 546964 records in current file
# Processed Tam_0018_Eng_m_8684.wav - 548871 records in current file
# Processed Tam_0018_Eng_m_8685.wav - 550487 records in current file
# Processed Tam_0018_Eng_m_8686.wav - 552469 records in current file
# Processed Tam_0018_Eng_m_8687.wav - 554357 records in current file
# Processed Tam_0018_Eng_m_8688.wav - 556026 records in current file
# Processed Tam_0018_Eng_m_8689.wav - 557011 records in current file
# Processed Tam_0018_Eng_m_8690.wav - 558721 records in current file
# Processed Tam_0018_Eng_m_8691.wav - 560068 records in current file
# Processed Tam_0018_Eng_m_8692.wav - 560872 records in current file
# Processed Tam_0020_Eng_m_0000.wav - 561397 records in current file
# Processed Tam_0020_Eng_m_0001.wav - 561972 records in current file
# Processed Tam_0020_Eng_m_0002.wav - 562822 records in current file
# Processed Tam_0020_Eng_m_0003.wav - 564047 records in current file
# Processed Tam_0020_Eng_m_0004.wav - 564607 records in current file
# Processed Tam_0020_Eng_m_0005.wav - 565098 records in current file
# Processed Tam_0020_Eng_m_8727.wav - 566002 records in current file
# Processed Tam_0020_Eng_m_8728.wav - 566737 records in current file
# Processed Tam_0020_Eng_m_8729.wav - 567456 records in current file
# Processed Tam_0020_Eng_m_8730.wav - 568388 records in current file
# Processed Tam_0020_Eng_m_8731.wav - 569179 records in current file
# Processed Tam_0020_Eng_m_8732.wav - 570305 records in current file
# Processed Tam_0020_Eng_m_8733.wav - 571565 records in current file
# Processed Tam_0020_Eng_m_8734.wav - 572800 records in current file
# Processed Tam_0020_Eng_m_8735.wav - 573757 records in current file
# Processed Tam_0020_Eng_m_8736.wav - 574186 records in current file
# Processed Tam_0020_Eng_m_8737.wav - 574921 records in current file
# Processed Tam_0020_Eng_m_8738.wav - 576106 records in current file
# Processed Tam_0020_Eng_m_8739.wav - 577469 records in current file
# Processed Tam_0020_Eng_m_8740.wav - 578669 records in current file
# Processed Tam_0020_Eng_m_8741.wav - 579285 records in current file
# Processed Tam_0020_Eng_m_8742.wav - 580529 records in current file
# Processed Tam_0020_Eng_m_8743.wav - 582248 records in current file
# Processed Tam_0020_Eng_m_8744.wav - 583330 records in current file
# Processed Tam_0020_Eng_m_8745.wav - 584334 records in current file
# Processed Tam_0020_Eng_m_8746.wav - 585869 records in current file
# Processed Tam_0020_Eng_m_8747.wav - 587663 records in current file
# Processed Tam_0020_Eng_m_8748.wav - 589192 records in current file
# Processed Tam_0020_Eng_m_8749.wav - 590680 records in current file
# Processed Tam_0020_Eng_m_8750.wav - 592909 records in current file
# Processed Tam_0020_Eng_m_8751.wav - 594263 records in current file
# Processed Tam_0020_Eng_m_8752.wav - 595379 records in current file
# Processed Tam_0020_Eng_m_8753.wav - 595911 records in current file
# Processed Tam_0020_Eng_m_8754.wav - 597033 records in current file
# Processed Tam_0020_Eng_m_8755.wav - 598065 records in current file
# Processed Tam_0020_Eng_m_8756.wav - 598587 records in current file
# Processed Tam_0020_Eng_m_8757.wav - 599222 records in current file
# Processed Tam_0020_Eng_m_8758.wav - 600607 records in current file
# Processed Tam_0020_Eng_m_8759.wav - 601904 records in current file
# Processed Tam_0020_Eng_m_8760.wav - 602323 records in current file
# Processed Tam_0020_Eng_m_8761.wav - 603158 records in current file
# Processed Tam_0024_Eng_f_0000.wav - 603765 records in current file
# Processed Tam_0024_Eng_f_0001.wav - 604447 records in current file
# Processed Tam_0024_Eng_f_0002.wav - 605294 records in current file
# Processed Tam_0024_Eng_f_0003.wav - 606582 records in current file
# Processed Tam_0024_Eng_f_0004.wav - 607258 records in current file
# Processed Tam_0024_Eng_f_0005.wav - 607859 records in current file
# Processed Tam_0024_Eng_f_8862.wav - 608963 records in current file
# Processed Tam_0024_Eng_f_8863.wav - 611098 records in current file
# Processed Tam_0024_Eng_f_8864.wav - 612286 records in current file
# Processed Tam_0024_Eng_f_8865.wav - 614355 records in current file
# Processed Tam_0024_Eng_f_8866.wav - 615949 records in current file
# Processed Tam_0024_Eng_f_8867.wav - 617459 records in current file
# Processed Tam_0024_Eng_f_8868.wav - 620228 records in current file
# Processed Tam_0024_Eng_f_8869.wav - 621800 records in current file
# Processed Tam_0024_Eng_f_8870.wav - 623519 records in current file
# Processed Tam_0024_Eng_f_8871.wav - 625116 records in current file
# Processed Tam_0024_Eng_f_8872.wav - 627373 records in current file
# Processed Tam_0024_Eng_f_8873.wav - 630545 records in current file
# Processed Tam_0024_Eng_f_8874.wav - 632427 records in current file
# Processed Tam_0024_Eng_f_8875.wav - 633871 records in current file
# Processed Tam_0024_Eng_f_8876.wav - 636862 records in current file
# Processed Tam_0024_Eng_f_8877.wav - 638491 records in current file
# Processed Tam_0024_Eng_f_8878.wav - 639523 records in current file
# Processed Tam_0024_Eng_f_8879.wav - 642067 records in current file
# Processed Tam_0024_Eng_f_8880.wav - 643827 records in current file
# Processed Tam_0024_Eng_f_8881.wav - 646296 records in current file
# Processed Tam_0024_Eng_f_8882.wav - 647728 records in current file
# Processed Tam_0024_Eng_f_8883.wav - 649510 records in current file
# Processed Tam_0024_Eng_f_8884.wav - 650511 records in current file
# Processed Tam_0024_Eng_f_8885.wav - 652127 records in current file
# Processed Tam_0024_Eng_f_8886.wav - 654168 records in current file
# Processed Tam_0024_Eng_f_8887.wav - 654784 records in current file
# Processed Tam_0024_Eng_f_8888.wav - 656397 records in current file
# Processed Tam_0024_Eng_f_8889.wav - 656894 records in current file
# Processed Tam_0024_Eng_f_8890.wav - 658010 records in current file
# Processed Tam_0024_Eng_f_8891.wav - 659951 records in current file
# Processed Tam_0024_Eng_f_8892.wav - 661655 records in current file
# Processed Tam_0024_Eng_f_8893.wav - 662502 records in current file
# Processed Tam_0024_Eng_f_8894.wav - 663559 records in current file
# Processed Tam_0025_Eng_f_0000.wav - 664153 records in current file
# Processed Tam_0025_Eng_f_0001.wav - 664744 records in current file
# Processed Tam_0025_Eng_f_0002.wav - 665623 records in current file
# Processed Tam_0025_Eng_f_0003.wav - 666836 records in current file
# Processed Tam_0025_Eng_f_0004.wav - 667543 records in current file
# Processed Tam_0025_Eng_f_0005.wav - 668194 records in current file
# Processed Tam_0025_Eng_f_8895.wav - 669345 records in current file
# Processed Tam_0025_Eng_f_8896.wav - 671080 records in current file
# Processed Tam_0025_Eng_f_8897.wav - 671787 records in current file
# Processed Tam_0025_Eng_f_8898.wav - 672625 records in current file
# Processed Tam_0025_Eng_f_8899.wav - 673529 records in current file
# Processed Tam_0025_Eng_f_8900.wav - 674592 records in current file
# Processed Tam_0025_Eng_f_8901.wav - 675699 records in current file
# Processed Tam_0025_Eng_f_8902.wav - 676524 records in current file
# Processed Tam_0025_Eng_f_8903.wav - 677840 records in current file
# Processed Tam_0025_Eng_f_8904.wav - 679225 records in current file
# Processed Tam_0025_Eng_f_8905.wav - 680288 records in current file
# Processed Tam_0025_Eng_f_8906.wav - 681214 records in current file
# Processed Tam_0025_Eng_f_8907.wav - 682346 records in current file
# Processed Tam_0025_Eng_f_8908.wav - 683747 records in current file
# Processed Tam_0025_Eng_f_8909.wav - 685254 records in current file
# Processed Tam_0025_Eng_f_8910.wav - 686295 records in current file
# Processed Tam_0025_Eng_f_8911.wav - 688377 records in current file
# Processed Tam_0025_Eng_f_8912.wav - 689402 records in current file
# Processed Tam_0025_Eng_f_8913.wav - 690331 records in current file
# Processed Tam_0025_Eng_f_8914.wav - 691238 records in current file
# Processed Tam_0025_Eng_f_8915.wav - 692604 records in current file
# Processed Tam_0025_Eng_f_8916.wav - 694111 records in current file
# Processed Tam_0025_Eng_f_8917.wav - 695493 records in current file
# Processed Tam_0025_Eng_f_8918.wav - 697437 records in current file
# Processed Tam_0025_Eng_f_8919.wav - 698353 records in current file
# Processed Tam_0025_Eng_f_8920.wav - 698944 records in current file
# Processed Tam_0025_Eng_f_8921.wav - 700166 records in current file
# Processed Tam_0025_Eng_f_8922.wav - 700517 records in current file
# Processed Tam_0025_Eng_f_8923.wav - 701861 records in current file
# Processed Tam_0025_Eng_f_8924.wav - 703096 records in current file
# Processed Tam_0025_Eng_f_8925.wav - 704296 records in current file
# Processed Tam_0025_Eng_f_8926.wav - 704693 records in current file
# Processed Tam_0026_Eng_f_0000.wav - 705315 records in current file
# Processed Tam_0026_Eng_f_0001.wav - 705869 records in current file
# Processed Tam_0026_Eng_f_0002.wav - 706538 records in current file
# Processed Tam_0026_Eng_f_0003.wav - 707542 records in current file
# Processed Tam_0026_Eng_f_0004.wav - 708164 records in current file
# Processed Tam_0026_Eng_f_0005.wav - 708777 records in current file
# Processed Tam_0026_Eng_f_8927.wav - 709715 records in current file
# Processed Tam_0026_Eng_f_8928.wav - 710712 records in current file
# Processed Tam_0026_Eng_f_8929.wav - 712522 records in current file
# Processed Tam_0026_Eng_f_8930.wav - 713541 records in current file
# Processed Tam_0026_Eng_f_8931.wav - 715354 records in current file
# Processed Tam_0026_Eng_f_8932.wav - 716961 records in current file
# Processed Tam_0026_Eng_f_8933.wav - 717943 records in current file
# Processed Tam_0026_Eng_f_8934.wav - 719409 records in current file
# Processed Tam_0026_Eng_f_8935.wav - 722813 records in current file
# Processed Tam_0026_Eng_f_8936.wav - 724467 records in current file
# Processed Tam_0026_Eng_f_8937.wav - 726555 records in current file
# Processed Tam_0026_Eng_f_8938.wav - 728384 records in current file
# Processed Tam_0026_Eng_f_8939.wav - 730478 records in current file
# Processed Tam_0026_Eng_f_8940.wav - 732963 records in current file
# Processed Tam_0026_Eng_f_8941.wav - 736026 records in current file
# Processed Tam_0026_Eng_f_8942.wav - 738545 records in current file
# Processed Tam_0026_Eng_f_8943.wav - 740727 records in current file
# Processed Tam_0026_Eng_f_8944.wav - 741584 records in current file
# Processed Tam_0026_Eng_f_8945.wav - 742213 records in current file
# Processed Tam_0026_Eng_f_8946.wav - 743723 records in current file
# Processed Tam_0026_Eng_f_8947.wav - 745542 records in current file
# Processed Tam_0026_Eng_f_8948.wav - 746546 records in current file
# Processed Tam_0026_Eng_f_8949.wav - 748275 records in current file
# Processed Tam_0026_Eng_f_8950.wav - 750160 records in current file
# Processed Tam_0026_Eng_f_8951.wav - 751757 records in current file
# Processed Tam_0026_Eng_f_8952.wav - 752554 records in current file
# Processed Tam_0026_Eng_f_8953.wav - 753308 records in current file
# Processed Tam_0026_Eng_f_8954.wav - 753980 records in current file
# Processed Tam_0026_Eng_f_8955.wav - 754746 records in current file
# Processed Tam_0026_Eng_f_8956.wav - 755512 records in current file
# Processed Tam_0026_Eng_f_8957.wav - 756119 records in current file
# Processed Tam_0026_Eng_f_8958.wav - 756816 records in current file
# Processed Tam_0026_Eng_f_8959.wav - 758251 records in current file
# Processed Tam_0026_Eng_f_8960.wav - 759045 records in current file
# Processed Tam_0026_Eng_f_8961.wav - 760114 records in current file
# Processed Tam_0026_Eng_f_8962.wav - 761102 records in current file
# Processed Tam_0026_Eng_f_8963.wav - 762196 records in current file
# Processed Tam_0026_Eng_f_8964.wav - 763372 records in current file
# Processed Tam_0028_Eng_f_0000.wav - 764004 records in current file
# Processed Tam_0028_Eng_f_0001.wav - 764573 records in current file
# Processed Tam_0028_Eng_f_0002.wav - 765433 records in current file
# Processed Tam_0028_Eng_f_0003.wav - 766699 records in current file
# Processed Tam_0028_Eng_f_0004.wav - 767284 records in current file
# Processed Tam_0028_Eng_f_0005.wav - 767866 records in current file
# Processed Tam_0028_Eng_f_8997.wav - 768960 records in current file
# Processed Tam_0028_Eng_f_8998.wav - 770239 records in current file
# Processed Tam_0028_Eng_f_8999.wav - 771068 records in current file
# Processed Tam_0028_Eng_f_9000.wav - 772334 records in current file
# Processed Tam_0028_Eng_f_9001.wav - 773516 records in current file
# Processed Tam_0028_Eng_f_9002.wav - 775213 records in current file
# Processed Tam_0028_Eng_f_9003.wav - 775926 records in current file
# Processed Tam_0028_Eng_f_9004.wav - 777042 records in current file
# Processed Tam_0028_Eng_f_9005.wav - 777658 records in current file
# Processed Tam_0028_Eng_f_9006.wav - 779187 records in current file
# Processed Tam_0028_Eng_f_9007.wav - 780147 records in current file
# Processed Tam_0028_Eng_f_9008.wav - 782141 records in current file
# Processed Tam_0028_Eng_f_9009.wav - 782985 records in current file
# Processed Tam_0028_Eng_f_9010.wav - 784101 records in current file
# Processed Tam_0028_Eng_f_9011.wav - 785470 records in current file
# Processed Tam_0028_Eng_f_9012.wav - 786927 records in current file
# Processed Tam_0028_Eng_f_9013.wav - 788653 records in current file
# Processed Tam_0028_Eng_f_9014.wav - 789713 records in current file
# Processed Tam_0028_Eng_f_9015.wav - 790588 records in current file
# Processed Tam_0028_Eng_f_9016.wav - 792223 records in current file
# Processed Tam_0028_Eng_f_9017.wav - 793261 records in current file
# Processed Tam_0028_Eng_f_9018.wav - 794890 records in current file
# Processed Tam_0028_Eng_f_9019.wav - 795856 records in current file
# Processed Tam_0028_Eng_f_9020.wav - 796666 records in current file
# Processed Tam_0028_Eng_f_9021.wav - 797863 records in current file
# Processed Tam_0028_Eng_f_9022.wav - 798695 records in current file
# Processed Tam_0028_Eng_f_9023.wav - 799774 records in current file
# Processed Tam_0028_Eng_f_9024.wav - 801403 records in current file
# Processed Tam_0028_Eng_f_9025.wav - 803025 records in current file
# Processed Tam_0028_Eng_f_9026.wav - 804160 records in current file
# Processed Tam_0028_Eng_f_9027.wav - 804960 records in current file
# Processed Tam_0028_Eng_f_9028.wav - 805929 records in current file
# Processed Tam_0028_Eng_f_9029.wav - 806617 records in current file
# Processed Tam_0028_Eng_f_9030.wav - 807621 records in current file
# Processed Tam_0028_Eng_f_9031.wav - 808272 records in current file
# Processed Tam_0029_Eng_m_0000.wav - 808926 records in current file
# Processed Tam_0029_Eng_m_0001.wav - 809473 records in current file
# Processed Tam_0029_Eng_m_0002.wav - 810170 records in current file
# Processed Tam_0029_Eng_m_0003.wav - 811280 records in current file
# Processed Tam_0029_Eng_m_0004.wav - 811868 records in current file
# Processed Tam_0029_Eng_m_0005.wav - 812462 records in current file
# Processed Tam_0029_Eng_m_9032.wav - 813481 records in current file
# Processed Tam_0029_Eng_m_9033.wav - 814575 records in current file
# Processed Tam_0029_Eng_m_9034.wav - 815091 records in current file
# Processed Tam_0029_Eng_m_9035.wav - 815654 records in current file
# Processed Tam_0029_Eng_m_9036.wav - 816561 records in current file
# Processed Tam_0029_Eng_m_9037.wav - 817536 records in current file
# Processed Tam_0029_Eng_m_9038.wav - 819121 records in current file
# Processed Tam_0029_Eng_m_9039.wav - 819918 records in current file
# ...
# Processed Tam_0001_Tam_m_0022.wav - 1795685 records in current file
# Processed Tam_0001_Tam_m_0023.wav - 1796645 records in current file
# Processed Tam_0001_Tam_m_0024.wav - 1797130 records in current file
# Processed Tam_0001_Tam_m_0025.wav - 1798359 records in current file
# Processed Tam_0001_Tam_m_0026.wav - 1799035 records in current file
# Processed Tam_0001_Tam_m_0027.wav - 1799845 records in current file
# Processed Tam_0001_Tam_m_0028.wav - 1800674 records in current file
# Processed Tam_0001_Tam_m_0029.wav - 1801540 records in current file
# Processed Tam_0001_Tam_m_0030.wav - 1802178 records in current file
# Processed Tam_0001_Tam_m_0031.wav - 1802900 records in current file
# Processed Tam_0001_Tam_m_0032.wav - 1803507 records in current file
# Processed Tam_0001_Tam_m_0033.wav - 1804404 records in current file
# Processed Tam_0001_Tam_m_0034.wav - 1804948 records in current file
# Processed Tam_0002_Tam_m_0000.wav - 1805836 records in current file
# Processed Tam_0002_Tam_m_0001.wav - 1806627 records in current file
# Processed Tam_0002_Tam_m_0002.wav - 1807803 records in current file
# Processed Tam_0002_Tam_m_0003.wav - 1808300 records in current file
# Processed Tam_0002_Tam_m_0004.wav - 1809241 records in current file
# Processed Tam_0002_Tam_m_0005.wav - 1810748 records in current file
# Processed Tam_0002_Tam_m_0006.wav - 1811520 records in current file
# Processed Tam_0002_Tam_m_0007.wav - 1812605 records in current file
# Processed Tam_0002_Tam_m_0008.wav - 1813527 records in current file
# Processed Tam_0002_Tam_m_0009.wav - 1814431 records in current file
# Processed Tam_0002_Tam_m_0010.wav - 1815194 records in current file
# Processed Tam_0002_Tam_m_0011.wav - 1815660 records in current file
# Processed Tam_0002_Tam_m_0012.wav - 1816701 records in current file
# Processed Tam_0002_Tam_m_0013.wav - 1817698 records in current file
# Processed Tam_0002_Tam_m_0014.wav - 1818749 records in current file
# Processed Tam_0002_Tam_m_0015.wav - 1820071 records in current file
# Processed Tam_0002_Tam_m_0016.wav - 1820962 records in current file
# Processed Tam_0002_Tam_m_0017.wav - 1821956 records in current file
# Processed Tam_0002_Tam_m_0018.wav - 1823213 records in current file
# Processed Tam_0002_Tam_m_0019.wav - 1824417 records in current file
# Processed Tam_0002_Tam_m_0020.wav - 1826008 records in current file
# Processed Tam_0002_Tam_m_0021.wav - 1827540 records in current file
# Processed Tam_0002_Tam_m_0022.wav - 1828150 records in current file
# Processed Tam_0002_Tam_m_0023.wav - 1829132 records in current file
# Processed Tam_0002_Tam_m_0024.wav - 1829761 records in current file
# Processed Tam_0002_Tam_m_0025.wav - 1830577 records in current file
# Processed Tam_0002_Tam_m_0026.wav - 1831127 records in current file
# Processed Tam_0002_Tam_m_0027.wav - 1831799 records in current file
# Processed Tam_0002_Tam_m_0028.wav - 1832690 records in current file
# Processed Tam_0002_Tam_m_0029.wav - 1833381 records in current file
# Processed Tam_0002_Tam_m_0030.wav - 1834494 records in current file
# Processed Tam_0002_Tam_m_0031.wav - 1835473 records in current file
# Processed Tam_0002_Tam_m_0032.wav - 1836405 records in current file
# Processed Tam_0002_Tam_m_0033.wav - 1836902 records in current file
# Processed Tam_0002_Tam_m_0034.wav - 1837468 records in current file
# Processed Tam_0004_Tam_m_0000.wav - 1838225 records in current file
# Processed Tam_0004_Tam_m_0001.wav - 1839022 records in current file
# Processed Tam_0004_Tam_m_0002.wav - 1839938 records in current file
# Processed Tam_0004_Tam_m_0003.wav - 1842154 records in current file
# Processed Tam_0004_Tam_m_0004.wav - 1842954 records in current file
# Processed Tam_0004_Tam_m_0005.wav - 1843926 records in current file
# Processed Tam_0004_Tam_m_0006.wav - 1844851 records in current file
# Processed Tam_0004_Tam_m_0007.wav - 1845389 records in current file
# Processed Tam_0004_Tam_m_0008.wav - 1846946 records in current file
# Processed Tam_0004_Tam_m_0009.wav - 1848159 records in current file
# Processed Tam_0004_Tam_m_0010.wav - 1848934 records in current file
# Processed Tam_0004_Tam_m_0011.wav - 1849859 records in current file
# Processed Tam_0004_Tam_m_0012.wav - 1850663 records in current file
# Processed Tam_0004_Tam_m_0013.wav - 1851439 records in current file
# Processed Tam_0004_Tam_m_0014.wav - 1852599 records in current file
# Processed Tam_0004_Tam_m_0015.wav - 1853799 records in current file
# Processed Tam_0004_Tam_m_0016.wav - 1855143 records in current file
# Processed Tam_0004_Tam_m_0017.wav - 1856315 records in current file
# Processed Tam_0004_Tam_m_0018.wav - 1857662 records in current file
# Processed Tam_0004_Tam_m_0019.wav - 1858381 records in current file
# Processed Tam_0004_Tam_m_0020.wav - 1859406 records in current file
# Processed Tam_0004_Tam_m_0021.wav - 1860972 records in current file
# Processed Tam_0004_Tam_m_0022.wav - 1861973 records in current file
# Processed Tam_0004_Tam_m_0023.wav - 1862942 records in current file
# Processed Tam_0004_Tam_m_0024.wav - 1863502 records in current file
# Processed Tam_0004_Tam_m_0025.wav - 1864184 records in current file
# Processed Tam_0004_Tam_m_0026.wav - 1864828 records in current file
# Processed Tam_0004_Tam_m_0027.wav - 1865413 records in current file
# Processed Tam_0004_Tam_m_0028.wav - 1866082 records in current file
# Processed Tam_0004_Tam_m_0029.wav - 1866858 records in current file
# Processed Tam_0004_Tam_m_0030.wav - 1867315 records in current file
# Processed Tam_0004_Tam_m_0031.wav - 1868265 records in current file
# Processed Tam_0004_Tam_m_0032.wav - 1868719 records in current file
# Processed Tam_0004_Tam_m_0033.wav - 1869157 records in current file
# Processed Tam_0004_Tam_m_0034.wav - 1869586 records in current file
# Processed Tam_0005_Tam_m_0000.wav - 1870399 records in current file
# Processed Tam_0005_Tam_m_0001.wav - 1871171 records in current file
# Processed Tam_0005_Tam_m_0002.wav - 1872490 records in current file
# Processed Tam_0005_Tam_m_0003.wav - 1873803 records in current file
# Processed Tam_0005_Tam_m_0004.wav - 1875072 records in current file
# Processed Tam_0005_Tam_m_0005.wav - 1877785 records in current file
# Processed Tam_0005_Tam_m_0006.wav - 1879976 records in current file
# Processed Tam_0005_Tam_m_0007.wav - 1881167 records in current file
# Processed Tam_0005_Tam_m_0008.wav - 1882108 records in current file
# Processed Tam_0005_Tam_m_0009.wav - 1884774 records in current file
# Processed Tam_0005_Tam_m_0010.wav - 1886078 records in current file
# Processed Tam_0005_Tam_m_0011.wav - 1887482 records in current file
# Processed Tam_0005_Tam_m_0012.wav - 1888592 records in current file
# Processed Tam_0005_Tam_m_0013.wav - 1889555 records in current file
# Processed Tam_0005_Tam_m_0014.wav - 1890468 records in current file
# Processed Tam_0005_Tam_m_0015.wav - 1891184 records in current file
# Processed Tam_0005_Tam_m_0016.wav - 1892016 records in current file
# Processed Tam_0005_Tam_m_0017.wav - 1892829 records in current file
# Processed Tam_0005_Tam_m_0018.wav - 1894064 records in current file
# Processed Tam_0005_Tam_m_0019.wav - 1895033 records in current file
# Processed Tam_0005_Tam_m_0020.wav - 1895996 records in current file
# Processed Tam_0005_Tam_m_0021.wav - 1896787 records in current file
# Processed Tam_0005_Tam_m_0022.wav - 1897287 records in current file
# Processed Tam_0005_Tam_m_0023.wav - 1898391 records in current file
# Processed Tam_0005_Tam_m_0024.wav - 1898966 records in current file
# Processed Tam_0005_Tam_m_0025.wav - 1899592 records in current file
# Processed Tam_0005_Tam_m_0026.wav - 1900589 records in current file
# Processed Tam_0005_Tam_m_0027.wav - 1901383 records in current file
# Processed Tam_0005_Tam_m_0028.wav - 1902171 records in current file
# Processed Tam_0005_Tam_m_0029.wav - 1902872 records in current file
# Processed Tam_0005_Tam_m_0030.wav - 1903669 records in current file
# Processed Tam_0005_Tam_m_0031.wav - 1904251 records in current file
# Processed Tam_0005_Tam_m_0032.wav - 1905139 records in current file
# Processed Tam_0005_Tam_m_0033.wav - 1905605 records in current file
# Processed Tam_0005_Tam_m_0034.wav - 1906384 records in current file
# Processed Tam_0006_Tam_m_0000.wav - 1907228 records in current file
# Processed Tam_0006_Tam_m_0001.wav - 1908185 records in current file
# Processed Tam_0006_Tam_m_0002.wav - 1909023 records in current file
# Processed Tam_0006_Tam_m_0003.wav - 1909692 records in current file
# Processed Tam_0006_Tam_m_0004.wav - 1910433 records in current file
# Processed Tam_0006_Tam_m_0005.wav - 1911246 records in current file
# Processed Tam_0006_Tam_m_0006.wav - 1911878 records in current file
# Processed Tam_0006_Tam_m_0007.wav - 1912460 records in current file
# Processed Tam_0006_Tam_m_0008.wav - 1913161 records in current file
# Processed Tam_0006_Tam_m_0009.wav - 1914208 records in current file
# Processed Tam_0006_Tam_m_0010.wav - 1915115 records in current file
# Processed Tam_0006_Tam_m_0011.wav - 1915884 records in current file
# Processed Tam_0006_Tam_m_0012.wav - 1917044 records in current file
# Processed Tam_0006_Tam_m_0013.wav - 1917913 records in current file
# Processed Tam_0006_Tam_m_0014.wav - 1918713 records in current file
# Processed Tam_0006_Tam_m_0015.wav - 1919526 records in current file
# Processed Tam_0006_Tam_m_0016.wav - 1920451 records in current file
# Processed Tam_0006_Tam_m_0017.wav - 1921605 records in current file
# Processed Tam_0006_Tam_m_0018.wav - 1922602 records in current file
# Processed Tam_0006_Tam_m_0019.wav - 1923481 records in current file
# Processed Tam_0006_Tam_m_0020.wav - 1924463 records in current file
# Processed Tam_0006_Tam_m_0021.wav - 1925554 records in current file
# Processed Tam_0006_Tam_m_0022.wav - 1925917 records in current file
# Processed Tam_0006_Tam_m_0023.wav - 1927077 records in current file
# Processed Tam_0006_Tam_m_0024.wav - 1928099 records in current file
# Processed Tam_0006_Tam_m_0025.wav - 1929240 records in current file
# Processed Tam_0006_Tam_m_0026.wav - 1929619 records in current file
# Processed Tam_0006_Tam_m_0027.wav - 1930257 records in current file
# Processed Tam_0006_Tam_m_0028.wav - 1930879 records in current file
# Processed Tam_0006_Tam_m_0029.wav - 1931376 records in current file
# Processed Tam_0006_Tam_m_0030.wav - 1931808 records in current file
# Processed Tam_0006_Tam_m_0031.wav - 1932777 records in current file
# Processed Tam_0006_Tam_m_0032.wav - 1933199 records in current file
# Processed Tam_0006_Tam_m_0033.wav - 1933746 records in current file
# Processed Tam_0006_Tam_m_0034.wav - 1934343 records in current file
# Processed Tam_0007_Tam_f_0000.wav - 1935259 records in current file
# Processed Tam_0007_Tam_f_0001.wav - 1936047 records in current file
# Processed Tam_0007_Tam_f_0002.wav - 1936763 records in current file
# Processed Tam_0007_Tam_f_0003.wav - 1937460 records in current file
# Processed Tam_0007_Tam_f_0004.wav - 1938354 records in current file
# Processed Tam_0007_Tam_f_0005.wav - 1938826 records in current file
# Processed Tam_0007_Tam_f_0006.wav - 1939730 records in current file
# Processed Tam_0007_Tam_f_0007.wav - 1940618 records in current file
# Processed Tam_0007_Tam_f_0008.wav - 1941762 records in current file
# Processed Tam_0007_Tam_f_0009.wav - 1942378 records in current file
# Processed Tam_0007_Tam_f_0010.wav - 1945094 records in current file
# Processed Tam_0007_Tam_f_0011.wav - 1945729 records in current file
# Processed Tam_0007_Tam_f_0012.wav - 1947898 records in current file
# Processed Tam_0007_Tam_f_0013.wav - 1949098 records in current file
# Processed Tam_0007_Tam_f_0014.wav - 1951377 records in current file
# Processed Tam_0007_Tam_f_0015.wav - 1952568 records in current file
# Processed Tam_0007_Tam_f_0016.wav - 1954115 records in current file
# Processed Tam_0007_Tam_f_0017.wav - 1954665 records in current file
# Processed Tam_0007_Tam_f_0018.wav - 1955072 records in current file
# Processed Tam_0007_Tam_f_0019.wav - 1955666 records in current file
# Processed Tam_0007_Tam_f_0020.wav - 1956576 records in current file
# Processed Tam_0007_Tam_f_0021.wav - 1957167 records in current file
# Processed Tam_0007_Tam_f_0022.wav - 1957693 records in current file
# Processed Tam_0007_Tam_f_0023.wav - 1958228 records in current file
# Processed Tam_0007_Tam_f_0024.wav - 1958835 records in current file
# Processed Tam_0007_Tam_f_0025.wav - 1959292 records in current file
# Processed Tam_0007_Tam_f_0026.wav - 1960092 records in current file
# Processed Tam_0007_Tam_f_0027.wav - 1960605 records in current file
# Processed Tam_0007_Tam_f_0028.wav - 1961002 records in current file
# Processed Tam_0007_Tam_f_0029.wav - 1961452 records in current file
# Processed Tam_0007_Tam_f_0030.wav - 1962299 records in current file
# Processed Tam_0007_Tam_f_0031.wav - 1963025 records in current file
# Processed Tam_0007_Tam_f_0032.wav - 1963563 records in current file
# Processed Tam_0007_Tam_f_0033.wav - 1964067 records in current file
# Processed Tam_0007_Tam_f_0034.wav - 1964574 records in current file
# Processed Tam_0008_Tam_m_0000.wav - 1965328 records in current file
# Processed Tam_0008_Tam_m_0001.wav - 1965982 records in current file
# Processed Tam_0008_Tam_m_0002.wav - 1966964 records in current file
# Processed Tam_0008_Tam_m_0003.wav - 1967927 records in current file
# Processed Tam_0008_Tam_m_0004.wav - 1968593 records in current file
# Processed Tam_0008_Tam_m_0005.wav - 1969547 records in current file
# Processed Tam_0008_Tam_m_0006.wav - 1970176 records in current file
# Processed Tam_0008_Tam_m_0007.wav - 1971008 records in current file
# Processed Tam_0008_Tam_m_0008.wav - 1971630 records in current file
# Processed Tam_0008_Tam_m_0009.wav - 1972446 records in current file
# Processed Tam_0008_Tam_m_0010.wav - 1973065 records in current file
# Processed Tam_0008_Tam_m_0011.wav - 1974025 records in current file
# Processed Tam_0008_Tam_m_0012.wav - 1974785 records in current file
# Processed Tam_0008_Tam_m_0013.wav - 1975682 records in current file
# Processed Tam_0008_Tam_m_0014.wav - 1976439 records in current file
# Processed Tam_0008_Tam_m_0015.wav - 1977233 records in current file
# Processed Tam_0008_Tam_m_0016.wav - 1978205 records in current file
# Processed Tam_0008_Tam_m_0017.wav - 1979102 records in current file
# Processed Tam_0008_Tam_m_0018.wav - 1979556 records in current file
# Processed Tam_0008_Tam_m_0019.wav - 1980544 records in current file
# Processed Tam_0008_Tam_m_0020.wav - 1981744 records in current file
# Processed Tam_0008_Tam_m_0021.wav - 1982776 records in current file
# Processed Tam_0008_Tam_m_0022.wav - 1983326 records in current file
# Processed Tam_0008_Tam_m_0023.wav - 1983802 records in current file
# Processed Tam_0008_Tam_m_0024.wav - 1984156 records in current file
# Processed Tam_0008_Tam_m_0025.wav - 1984713 records in current file
# Processed Tam_0008_Tam_m_0026.wav - 1985117 records in current file
# Processed Tam_0008_Tam_m_0027.wav - 1985777 records in current file
# Processed Tam_0008_Tam_m_0028.wav - 1986134 records in current file
# Processed Tam_0008_Tam_m_0029.wav - 1986563 records in current file
# Processed Tam_0008_Tam_m_0030.wav - 1987167 records in current file
# Processed Tam_0008_Tam_m_0031.wav - 1987717 records in current file
# Processed Tam_0008_Tam_m_0032.wav - 1988192 records in current file
# Processed Tam_0008_Tam_m_0033.wav - 1988627 records in current file
# Processed Tam_0008_Tam_m_0034.wav - 1989174 records in current file
# Processed Tam_0012_Tam_m_0000.wav - 1989856 records in current file
# Processed Tam_0012_Tam_m_0001.wav - 1990588 records in current file
# Processed Tam_0012_Tam_m_0002.wav - 1991826 records in current file
# Processed Tam_0012_Tam_m_0003.wav - 1992930 records in current file
# Processed Tam_0012_Tam_m_0004.wav - 1993684 records in current file
# Processed Tam_0012_Tam_m_0005.wav - 1994322 records in current file
# Processed Tam_0012_Tam_m_0006.wav - 1995007 records in current file
# Processed Tam_0012_Tam_m_0007.wav - 1995961 records in current file
# Processed Tam_0012_Tam_m_0008.wav - 1997152 records in current file
# Processed Tam_0012_Tam_m_0009.wav - 1998318 records in current file
# Processed Tam_0012_Tam_m_0010.wav - 1999475 records in current file
# Feature extraction and CSV writing completed

# %%
import pandas as pd

def remove_zero_columns_from_files(file_paths, columns_to_remove):
    for file_path in file_paths:
        # Load the CSV file into a DataFrame
        df = pd.read_csv(file_path)
        
        # Check if columns to remove exist in the DataFrame
        existing_columns_to_remove = [col for col in columns_to_remove if col in df.columns]
        
        # Drop the columns that are all zeros
        df = df.drop(columns=existing_columns_to_remove)
        
        # Save the modified DataFrame back to CSV
        df.to_csv(file_path, index=False)
        print(f"Updated file saved: {file_path}")

# List of file paths to your CSV files
file_paths = [
    r'C:\Users\deeps\VSCodeProjects\Jio_internship_project_2\audio_features1.csv'
]

# List of columns that are all zeros across all files
zero_columns_across_all_files = [
    'mfcc_std_1', 'mfcc_skew_1', 'mfcc_kurt_1',
    'mfcc_kurt_2', 'mfcc_kurt_3', 'mfcc_kurt_4', 
    'mfcc_kurt_5', 'mfcc_kurt_6', 'mfcc_kurt_7', 
    'mfcc_kurt_9', 'mfcc_kurt_13','mfcc_skew_3'
]

# Remove the zero columns from all files and save them
remove_zero_columns_from_files(file_paths, zero_columns_across_all_files)
# Out:
# Updated file saved: C:\Users\deeps\VSCodeProjects\Jio_internship_project_2\audio_features1.csv

# %%
import librosa
import csv
import os
import numpy as np
from scipy.stats import skew, kurtosis

def extract_features(audio, sr, output_label):
    frame_size = int(0.03 * sr)
    hop_length = int(0.01 * sr)

    # Extract MFCC features
    mfcc = librosa.feature.mfcc(y=audio, sr=sr, n_mfcc=13, hop_length=hop_length, n_fft=frame_size).astype(np.float16)
    delta_mfcc = librosa.feature.delta(mfcc).astype(np.float16)
    delta2_mfcc = librosa.feature.delta(mfcc, order=2).astype(np.float16)

    # Extract Pitch (Fundamental Frequency)
    pitches, _ = librosa.core.piptrack(y=audio, sr=sr, hop_length=hop_length, n_fft=frame_size)
    pitch = np.mean(pitches[pitches > 0]) if np.any(pitches > 0) else 0.0

    # Extract Spectral Features
    spectral_centroid = librosa.feature.spectral_centroid(y=audio, sr=sr, hop_length=hop_length).flatten().astype(np.float16)
    spectral_bandwidth = librosa.feature.spectral_bandwidth(y=audio, sr=sr, hop_length=hop_length).flatten().astype(np.float16)

    # Extract Zero-Crossing Rate
    zcr = librosa.feature.zero_crossing_rate(y=audio, hop_length=hop_length, frame_length=frame_size).flatten().astype(np.float16)

    # Extract RMS Energy
    rms = librosa.feature.rms(y=audio, hop_length=hop_length, frame_length=frame_size).flatten().astype(np.float16)

    # Statistics for MFCCs
    mfccs_stats = np.hstack([np.mean(mfcc, axis=1), np.std(mfcc, axis=1),
                              skew(mfcc, axis=1), kurtosis(mfcc, axis=1)])

    # Ensure consistent lengths
    num_frames = min(
        mfcc.shape[1],
        delta_mfcc.shape[1],
        delta2_mfcc.shape[1],
        len(zcr),
        len(rms),
        len(spectral_centroid),
        len(spectral_bandwidth)
    )

    features = []
    for i in range(num_frames):
        frame_features = np.concatenate((
            mfcc[:, i],
            delta_mfcc[:, i],
            delta2_mfcc[:, i],
            [pitch],
            [zcr[i]],
            [rms[i]],
            [spectral_centroid[i]],
            [spectral_bandwidth[i]],
            mfccs_stats
        ))
        features.append([frame_features, output_label])

    return features

def get_speaker_info(file_path):
    speaker_dict = {}
    with open(file_path, 'r') as f:
        next(f)  # Skip header
        for line in f:
            line_parts = line.split()
            gender = np.int8(1 if line_parts[1] == 'Male' else 0)
            age = round(float(line_parts[7]))
            age_group = [np.int8(0)] * 4
            age_index = min(max((age // 10) - 1, 0), 3)
            age_group[age_index] = np.int8(1)
            speaker_dict[line_parts[0]] = [gender] + age_group
    return speaker_dict

def write_header(writer):
    header = ['mfcc_' + str(i+1) for i in range(13)] + \
             ['delta_mfcc_' + str(i+1) for i in range(13)] + \
             ['delta2_mfcc_' + str(i+1) for i in range(13)] + \
             ['pitch', 'zcr', 'rms', 'spectral_centroid', 'spectral_bandwidth'] + \
             ['mfcc_mean_' + str(i+1) for i in range(13)] + \
             ['mfcc_std_' + str(i+1) for i in range(13)] + \
             ['mfcc_skew_' + str(i+1) for i in range(13)] + \
             ['mfcc_kurt_' + str(i+1) for i in range(13)] + \
             ['gender'] + ['age_group_' + str(i+1) for i in range(4)]
    writer.writerow(header)

def process_audio_files():
    source_dirs = [
        r'C:\Users\deeps\VSCodeProjects\Jio_internship_project_2\Tamil_master - Copy\Tamil_master\English_Tamil',
        r'C:\Users\deeps\VSCodeProjects\Jio_internship_project_2\Tamil_master - Copy\Tamil_master\Tamil',
        r'C:\Users\deeps\VSCodeProjects\Jio_internship_project_2\Malayalam_master - Copy\Malayalam_master\English_Malayalam',
        r'C:\Users\deeps\VSCodeProjects\Jio_internship_project_2\Malayalam_master - Copy\Malayalam_master\Malayalam',
        r'C:\Users\deeps\VSCodeProjects\Jio_internship_project_2\Hindi_master - Copy\Hindi_master\English_Hindi',
        r'C:\Users\deeps\VSCodeProjects\Jio_internship_project_2\Hindi_master - Copy\Hindi_master\Hindi',
        r'C:\Users\deeps\VSCodeProjects\Jio_internship_project_2\Telugu_master - Copy\Telugu_master\English_Telugu',
        r'C:\Users\deeps\VSCodeProjects\Jio_internship_project_2\Telugu_master - Copy\Telugu_master\Telugu',
        r'C:\Users\deeps\VSCodeProjects\Jio_internship_project_2\Kannada_master - Copy\Kannada_master\English_Kannada',
        r'C:\Users\deeps\VSCodeProjects\Jio_internship_project_2\Kannada_master - Copy\Kannada_master\Kannada'
    ]
    speaker_info_file = r'C:\Users\deeps\VSCodeProjects\Jio_internship_project_2\total_spkrinfo.list'
    speaker_dict = get_speaker_info(speaker_info_file)

    csv_file_number = 1
    record_count = 0
    max_records_per_file = 2000000

    csv_file = f'audio_features{csv_file_number}.csv'
    f = open(csv_file, 'a', newline='')
    writer = csv.writer(f)
    write_header(writer)

    for source_dir in source_dirs:
        for root, _, files in os.walk(source_dir):
            for file in files:
                if file.endswith('.wav'):
                    audio_file = os.path.join(root, file)
                    speaker_id = file[:8]
                    output_label = speaker_dict.get(speaker_id, [0] * 5)
                    audio, sr = librosa.load(audio_file, sr=None)
                    features = extract_features(audio, sr, output_label)
                    for frame_features in features:
                        writer.writerow(frame_features[0].tolist() + [frame_features[1][0]] + frame_features[1][1:])
                        record_count += 1

                        if record_count >= max_records_per_file:
                            f.close()
                            csv_file_number += 1
                            csv_file = f'audio_features{csv_file_number}.csv'
                            f = open(csv_file, 'a', newline='')
                            writer = csv.writer(f)
                            write_header(writer)
                            record_count = 0

                    print(f'Processed {file} - {record_count} records in current file')

    f.close()
    print("Feature extraction and CSV writing completed")

if __name__ == '__main__':
    process_audio_files()
# Out:
# c:\Users\deeps\anaconda3\Lib\site-packages\numpy\core\_methods.py:215: RuntimeWarning: overflow encountered in reduce
#   arrmean = umr_sum(arr, axis, dtype, keepdims=True, where=where)
# c:\Users\deeps\anaconda3\Lib\site-packages\numpy\core\_methods.py:250: RuntimeWarning: overflow encountered in reduce
#   ret = umr_sum(x, axis, dtype, out, keepdims=keepdims, where=where)
# c:\Users\deeps\anaconda3\Lib\site-packages\scipy\stats\_stats_py.py:1094: RuntimeWarning: overflow encountered in multiply
#   s *= a_zero_mean
# c:\Users\deeps\anaconda3\Lib\site-packages\numpy\core\_methods.py:181: RuntimeWarning: invalid value encountered in reduce
#   ret = umr_sum(arr, axis, dtype, out, keepdims, where=where)
# c:\Users\deeps\anaconda3\Lib\site-packages\scipy\stats\_stats_py.py:1092: RuntimeWarning: overflow encountered in square
#   s = s**2
# Processed Tam_0003_Eng_m_0000.wav - 572 records in current file
# Processed Tam_0003_Eng_m_0001.wav - 1107 records in current file
# Processed Tam_0003_Eng_m_0002.wav - 1889 records in current file
# Processed Tam_0003_Eng_m_0003.wav - 3171 records in current file
# Processed Tam_0003_Eng_m_0004.wav - 3778 records in current file
# c:\Users\deeps\anaconda3\Lib\site-packages\scipy\stats\_stats_py.py:1088: RuntimeWarning: overflow encountered in square
#   s = a_zero_mean**2
# Processed Tam_0003_Eng_m_0005.wav - 4307 records in current file
# Processed Tam_0003_Eng_m_8150.wav - 5486 records in current file
# Processed Tam_0003_Eng_m_8151.wav - 6021 records in current file
# Processed Tam_0003_Eng_m_8152.wav - 8084 records in current file
# Processed Tam_0003_Eng_m_8153.wav - 10238 records in current file
# Processed Tam_0003_Eng_m_8154.wav - 11504 records in current file
# Processed Tam_0003_Eng_m_8155.wav - 12555 records in current file
# Processed Tam_0003_Eng_m_8156.wav - 14259 records in current file
# Processed Tam_0003_Eng_m_8157.wav - 15641 records in current file
# Processed Tam_0003_Eng_m_8158.wav - 18013 records in current file
# Processed Tam_0003_Eng_m_8159.wav - 19217 records in current file
# Processed Tam_0003_Eng_m_8160.wav - 20833 records in current file
# Processed Tam_0003_Eng_m_8161.wav - 23418 records in current file
# Processed Tam_0003_Eng_m_8162.wav - 24594 records in current file
# Processed Tam_0003_Eng_m_8163.wav - 26535 records in current file
# Processed Tam_0003_Eng_m_8164.wav - 27735 records in current file
# Processed Tam_0003_Eng_m_8165.wav - 29145 records in current file
# Processed Tam_0003_Eng_m_8166.wav - 30621 records in current file
# Processed Tam_0003_Eng_m_8167.wav - 31972 records in current file
# Processed Tam_0003_Eng_m_8168.wav - 33326 records in current file
# Processed Tam_0003_Eng_m_8169.wav - 35073 records in current file
# Processed Tam_0003_Eng_m_8170.wav - 36783 records in current file
# Processed Tam_0003_Eng_m_8171.wav - 37409 records in current file
# Processed Tam_0003_Eng_m_8172.wav - 38206 records in current file
# Processed Tam_0003_Eng_m_8173.wav - 39978 records in current file
# Processed Tam_0003_Eng_m_8174.wav - 41460 records in current file
# Processed Tam_0003_Eng_m_8175.wav - 42176 records in current file
# Processed Tam_0003_Eng_m_8176.wav - 42642 records in current file
# Processed Tam_0003_Eng_m_8177.wav - 43511 records in current file
# Processed Tam_0003_Eng_m_8178.wav - 44262 records in current file
# Processed Tam_0003_Eng_m_8179.wav - 44806 records in current file
# Processed Tam_0003_Eng_m_8180.wav - 45500 records in current file
# Processed Tam_0003_Eng_m_8181.wav - 46079 records in current file
# Processed Tam_0003_Eng_m_8182.wav - 46948 records in current file
# Processed Tam_0003_Eng_m_8183.wav - 47858 records in current file
# Processed Tam_0003_Eng_m_8184.wav - 48637 records in current file
# Processed Tam_0003_Eng_m_8185.wav - 49347 records in current file
# Processed Tam_0009_Eng_m_0000.wav - 50113 records in current file
# Processed Tam_0009_Eng_m_0001.wav - 50804 records in current file
# Processed Tam_0009_Eng_m_0002.wav - 51683 records in current file
# Processed Tam_0009_Eng_m_0003.wav - 52865 records in current file
# Processed Tam_0009_Eng_m_0004.wav - 53469 records in current file
# Processed Tam_0009_Eng_m_0005.wav - 54079 records in current file
# Processed Tam_0009_Eng_m_8367.wav - 55789 records in current file
# Processed Tam_0009_Eng_m_8368.wav - 56639 records in current file
# Processed Tam_0009_Eng_m_8369.wav - 58115 records in current file
# Processed Tam_0009_Eng_m_8370.wav - 59028 records in current file
# Processed Tam_0009_Eng_m_8371.wav - 59679 records in current file
# Processed Tam_0009_Eng_m_8372.wav - 61086 records in current file
# Processed Tam_0009_Eng_m_8373.wav - 62115 records in current file
# Processed Tam_0009_Eng_m_8374.wav - 63087 records in current file
# Processed Tam_0009_Eng_m_8375.wav - 63828 records in current file
# Processed Tam_0009_Eng_m_8376.wav - 65291 records in current file
# Processed Tam_0009_Eng_m_8377.wav - 65910 records in current file
# Processed Tam_0009_Eng_m_8378.wav - 66714 records in current file
# Processed Tam_0009_Eng_m_8379.wav - 67899 records in current file
# Processed Tam_0009_Eng_m_8380.wav - 69731 records in current file
# Processed Tam_0009_Eng_m_8381.wav - 70956 records in current file
# Processed Tam_0009_Eng_m_8382.wav - 72478 records in current file
# Processed Tam_0009_Eng_m_8383.wav - 73657 records in current file
# Processed Tam_0009_Eng_m_8384.wav - 75511 records in current file
# Processed Tam_0009_Eng_m_8385.wav - 76305 records in current file
# Processed Tam_0009_Eng_m_8386.wav - 78262 records in current file
# Processed Tam_0009_Eng_m_8387.wav - 80047 records in current file
# Processed Tam_0009_Eng_m_8388.wav - 81623 records in current file
# Processed Tam_0009_Eng_m_8389.wav - 83449 records in current file
# Processed Tam_0009_Eng_m_8390.wav - 84925 records in current file
# Processed Tam_0009_Eng_m_8391.wav - 86760 records in current file
# Processed Tam_0009_Eng_m_8392.wav - 87645 records in current file
# Processed Tam_0009_Eng_m_8393.wav - 88249 records in current file
# Processed Tam_0009_Eng_m_8394.wav - 88915 records in current file
# Processed Tam_0009_Eng_m_8395.wav - 89728 records in current file
# Processed Tam_0009_Eng_m_8396.wav - 90822 records in current file
# Processed Tam_0009_Eng_m_8397.wav - 91466 records in current file
# Processed Tam_0010_Eng_m_0000.wav - 92042 records in current file
# Processed Tam_0010_Eng_m_0001.wav - 92546 records in current file
# Processed Tam_0010_Eng_m_0002.wav - 93222 records in current file
# Processed Tam_0010_Eng_m_0003.wav - 94157 records in current file
# Processed Tam_0010_Eng_m_0004.wav - 94714 records in current file
# Processed Tam_0010_Eng_m_0005.wav - 95199 records in current file
# Processed Tam_0010_Eng_m_8398.wav - 96743 records in current file
# Processed Tam_0010_Eng_m_8399.wav - 97559 records in current file
# Processed Tam_0010_Eng_m_8400.wav - 98685 records in current file
# Processed Tam_0010_Eng_m_8401.wav - 99764 records in current file
# Processed Tam_0010_Eng_m_8402.wav - 100971 records in current file
# Processed Tam_0010_Eng_m_8403.wav - 101818 records in current file
# Processed Tam_0010_Eng_m_8404.wav - 103893 records in current file
# Processed Tam_0010_Eng_m_8405.wav - 105075 records in current file
# Processed Tam_0010_Eng_m_8406.wav - 105835 records in current file
# Processed Tam_0010_Eng_m_8407.wav - 107498 records in current file
# Processed Tam_0010_Eng_m_8408.wav - 109148 records in current file
# Processed Tam_0010_Eng_m_8409.wav - 110008 records in current file
# Processed Tam_0010_Eng_m_8410.wav - 111368 records in current file
# Processed Tam_0010_Eng_m_8411.wav - 112681 records in current file
# Processed Tam_0010_Eng_m_8412.wav - 113794 records in current file
# Processed Tam_0010_Eng_m_8413.wav - 115110 records in current file
# Processed Tam_0010_Eng_m_8414.wav - 115892 records in current file
# Processed Tam_0010_Eng_m_8415.wav - 117002 records in current file
# Processed Tam_0010_Eng_m_8416.wav - 118140 records in current file
# Processed Tam_0010_Eng_m_8417.wav - 118822 records in current file
# Processed Tam_0010_Eng_m_8418.wav - 119891 records in current file
# Processed Tam_0010_Eng_m_8419.wav - 121104 records in current file
# Processed Tam_0010_Eng_m_8420.wav - 122183 records in current file
# Processed Tam_0010_Eng_m_8421.wav - 123705 records in current file
# Processed Tam_0010_Eng_m_8422.wav - 124715 records in current file
# Processed Tam_0010_Eng_m_8423.wav - 125284 records in current file
# Processed Tam_0010_Eng_m_8424.wav - 125922 records in current file
# Processed Tam_0010_Eng_m_8425.wav - 126451 records in current file
# Processed Tam_0010_Eng_m_8426.wav - 126908 records in current file
# Processed Tam_0010_Eng_m_8427.wav - 127743 records in current file
# Processed Tam_0010_Eng_m_8428.wav - 128453 records in current file
# Processed Tam_0010_Eng_m_8429.wav - 129113 records in current file
# Processed Tam_0010_Eng_m_8430.wav - 129910 records in current file
# Processed Tam_0010_Eng_m_8431.wav - 130448 records in current file
# Processed Tam_0010_Eng_m_8432.wav - 131183 records in current file
# Processed Tam_0011_Eng_f_0000.wav - 131843 records in current file
# Processed Tam_0011_Eng_f_0001.wav - 132631 records in current file
# Processed Tam_0011_Eng_f_0002.wav - 133416 records in current file
# Processed Tam_0011_Eng_f_0003.wav - 134551 records in current file
# Processed Tam_0011_Eng_f_0004.wav - 135205 records in current file
# Processed Tam_0011_Eng_f_0005.wav - 135877 records in current file
# Processed Tam_0011_Eng_f_8433.wav - 136968 records in current file
# Processed Tam_0011_Eng_f_8434.wav - 137825 records in current file
# Processed Tam_0011_Eng_f_8435.wav - 139088 records in current file
# Processed Tam_0011_Eng_f_8436.wav - 140676 records in current file
# Processed Tam_0011_Eng_f_8437.wav - 141383 records in current file
# Processed Tam_0011_Eng_f_8438.wav - 142977 records in current file
# Processed Tam_0011_Eng_f_8439.wav - 144346 records in current file
# Processed Tam_0011_Eng_f_8440.wav - 145934 records in current file
# Processed Tam_0011_Eng_f_8441.wav - 146381 records in current file
# Processed Tam_0011_Eng_f_8442.wav - 148547 records in current file
# Processed Tam_0011_Eng_f_8443.wav - 149376 records in current file
# Processed Tam_0011_Eng_f_8444.wav - 150492 records in current file
# Processed Tam_0011_Eng_f_8445.wav - 151461 records in current file
# Processed Tam_0011_Eng_f_8446.wav - 153161 records in current file
# Processed Tam_0011_Eng_f_8447.wav - 155008 records in current file
# Processed Tam_0011_Eng_f_8448.wav - 158768 records in current file
# Processed Tam_0011_Eng_f_8449.wav - 160212 records in current file
# Processed Tam_0011_Eng_f_8450.wav - 161322 records in current file
# Processed Tam_0011_Eng_f_8451.wav - 163163 records in current file
# Processed Tam_0011_Eng_f_8452.wav - 165179 records in current file
# Processed Tam_0011_Eng_f_8453.wav - 166367 records in current file
# Processed Tam_0011_Eng_f_8454.wav - 168627 records in current file
# c:\Users\deeps\anaconda3\Lib\site-packages\scipy\stats\_stats_py.py:1074: RuntimeWarning: overflow encountered in divide
#   rel_diff = np.max(np.abs(a_zero_mean), axis=axis,
# Processed Tam_0011_Eng_f_8455.wav - 170249 records in current file
# Processed Tam_0011_Eng_f_8456.wav - 171981 records in current file
# Processed Tam_0011_Eng_f_8457.wav - 172835 records in current file
# Processed Tam_0011_Eng_f_8458.wav - 174423 records in current file
# Processed Tam_0011_Eng_f_8459.wav - 175555 records in current file
# Processed Tam_0011_Eng_f_8460.wav - 176259 records in current file
# Processed Tam_0011_Eng_f_8461.wav - 177535 records in current file
# Processed Tam_0011_Eng_f_8462.wav - 178823 records in current file
# Processed Tam_0011_Eng_f_8463.wav - 179383 records in current file
# Processed Tam_0011_Eng_f_8464.wav - 180359 records in current file
# Processed Tam_0011_Eng_f_8465.wav - 181244 records in current file
# Processed Tam_0015_Eng_m_0000.wav - 181798 records in current file
# Processed Tam_0015_Eng_m_0001.wav - 182342 records in current file
# Processed Tam_0015_Eng_m_0002.wav - 183052 records in current file
# Processed Tam_0015_Eng_m_0003.wav - 184131 records in current file
# Processed Tam_0015_Eng_m_0004.wav - 184778 records in current file
# Processed Tam_0015_Eng_m_0005.wav - 185325 records in current file
# Processed Tam_0015_Eng_m_8561.wav - 187016 records in current file
# Processed Tam_0015_Eng_m_8562.wav - 188542 records in current file
# Processed Tam_0015_Eng_m_8563.wav - 190318 records in current file
# Processed Tam_0015_Eng_m_8564.wav - 192003 records in current file
# Processed Tam_0015_Eng_m_8565.wav - 193025 records in current file
# Processed Tam_0015_Eng_m_8566.wav - 194472 records in current file
# Processed Tam_0015_Eng_m_8567.wav - 195838 records in current file
# Processed Tam_0015_Eng_m_8568.wav - 197157 records in current file
# Processed Tam_0015_Eng_m_8569.wav - 198357 records in current file
# Processed Tam_0015_Eng_m_8570.wav - 200139 records in current file
# Processed Tam_0015_Eng_m_8571.wav - 201443 records in current file
# Processed Tam_0015_Eng_m_8572.wav - 202447 records in current file
# Processed Tam_0015_Eng_m_8573.wav - 203635 records in current file
# Processed Tam_0015_Eng_m_8574.wav - 205626 records in current file
# Processed Tam_0015_Eng_m_8575.wav - 206708 records in current file
# Processed Tam_0015_Eng_m_8576.wav - 208049 records in current file
# Processed Tam_0015_Eng_m_8577.wav - 209740 records in current file
# Processed Tam_0015_Eng_m_8578.wav - 210509 records in current file
# Processed Tam_0015_Eng_m_8579.wav - 211585 records in current file
# Processed Tam_0015_Eng_m_8580.wav - 212470 records in current file
# Processed Tam_0015_Eng_m_8581.wav - 213711 records in current file
# Processed Tam_0015_Eng_m_8582.wav - 214871 records in current file
# Processed Tam_0015_Eng_m_8583.wav - 216396 records in current file
# Processed Tam_0015_Eng_m_8584.wav - 217740 records in current file
# Processed Tam_0015_Eng_m_8585.wav - 218897 records in current file
# Processed Tam_0015_Eng_m_8586.wav - 220041 records in current file
# Processed Tam_0015_Eng_m_8587.wav - 220720 records in current file
# Processed Tam_0015_Eng_m_8588.wav - 221471 records in current file
# Processed Tam_0015_Eng_m_8589.wav - 222928 records in current file
# Processed Tam_0015_Eng_m_8590.wav - 224207 records in current file
# Processed Tam_0017_Eng_m_0000.wav - 224761 records in current file
# Processed Tam_0017_Eng_m_0001.wav - 225224 records in current file
# Processed Tam_0017_Eng_m_0002.wav - 225903 records in current file
# Processed Tam_0017_Eng_m_0003.wav - 227050 records in current file
# Processed Tam_0017_Eng_m_0004.wav - 227635 records in current file
# Processed Tam_0017_Eng_m_0005.wav - 228204 records in current file
# Processed Tam_0017_Eng_m_8626.wav - 229042 records in current file
# Processed Tam_0017_Eng_m_8627.wav - 229833 records in current file
# Processed Tam_0017_Eng_m_8628.wav - 230671 records in current file
# Processed Tam_0017_Eng_m_8629.wav - 231712 records in current file
# Processed Tam_0017_Eng_m_8630.wav - 232859 records in current file
# Processed Tam_0017_Eng_m_8631.wav - 233610 records in current file
# Processed Tam_0017_Eng_m_8632.wav - 234736 records in current file
# Processed Tam_0017_Eng_m_8633.wav - 235755 records in current file
# Processed Tam_0017_Eng_m_8634.wav - 236890 records in current file
# Processed Tam_0017_Eng_m_8635.wav - 237731 records in current file
# Processed Tam_0017_Eng_m_8636.wav - 238463 records in current file
# Processed Tam_0017_Eng_m_8637.wav - 239617 records in current file
# Processed Tam_0017_Eng_m_8638.wav - 240733 records in current file
# Processed Tam_0017_Eng_m_8639.wav - 242202 records in current file
# Processed Tam_0017_Eng_m_8640.wav - 243831 records in current file
# Processed Tam_0017_Eng_m_8641.wav - 246044 records in current file
# Processed Tam_0017_Eng_m_8642.wav - 247138 records in current file
# Processed Tam_0017_Eng_m_8643.wav - 247817 records in current file
# Processed Tam_0017_Eng_m_8644.wav - 248583 records in current file
# Processed Tam_0017_Eng_m_8645.wav - 250680 records in current file
# Processed Tam_0017_Eng_m_8646.wav - 251752 records in current file
# Processed Tam_0017_Eng_m_8647.wav - 253202 records in current file
# Processed Tam_0017_Eng_m_8648.wav - 254396 records in current file
# Processed Tam_0017_Eng_m_8649.wav - 254956 records in current file
# Processed Tam_0017_Eng_m_8650.wav - 255660 records in current file
# Processed Tam_0017_Eng_m_8651.wav - 257354 records in current file
# Processed Tam_0017_Eng_m_8652.wav - 257745 records in current file
# Processed Tam_0017_Eng_m_8653.wav - 258717 records in current file
# Processed Tam_0017_Eng_m_8654.wav - 259914 records in current file
# Processed Tam_0017_Eng_m_8655.wav - 260352 records in current file
# Processed Tam_0017_Eng_m_8656.wav - 260978 records in current file
# Processed Tam_0017_Eng_m_8657.wav - 262178 records in current file
# Processed Tam_0017_Eng_m_8658.wav - 262885 records in current file
# Processed Tam_0017_Eng_m_8659.wav - 263689 records in current file
# Processed Tam_0017_Eng_m_8660.wav - 265452 records in current file
# Processed Tam_0017_Eng_m_8661.wav - 265990 records in current file
# Processed Tam_0019_Eng_m_0000.wav - 266650 records in current file
# Processed Tam_0019_Eng_m_0001.wav - 267154 records in current file
# Processed Tam_0019_Eng_m_0002.wav - 267883 records in current file
# Processed Tam_0019_Eng_m_0003.wav - 268993 records in current file
# Processed Tam_0019_Eng_m_0004.wav - 269659 records in current file
# Processed Tam_0019_Eng_m_0005.wav - 270238 records in current file
# Processed Tam_0019_Eng_m_8693.wav - 271623 records in current file
# Processed Tam_0019_Eng_m_8694.wav - 272870 records in current file
# Processed Tam_0019_Eng_m_8695.wav - 273471 records in current file
# Processed Tam_0019_Eng_m_8696.wav - 274400 records in current file
# Processed Tam_0019_Eng_m_8697.wav - 275213 records in current file
# Processed Tam_0019_Eng_m_8698.wav - 276023 records in current file
# Processed Tam_0019_Eng_m_8699.wav - 277061 records in current file
# Processed Tam_0019_Eng_m_8700.wav - 277946 records in current file
# Processed Tam_0019_Eng_m_8701.wav - 279097 records in current file
# Processed Tam_0019_Eng_m_8702.wav - 280129 records in current file
# Processed Tam_0019_Eng_m_8703.wav - 280829 records in current file
# Processed Tam_0019_Eng_m_8704.wav - 281717 records in current file
# Processed Tam_0019_Eng_m_8705.wav - 283580 records in current file
# Processed Tam_0019_Eng_m_8706.wav - 284634 records in current file
# Processed Tam_0019_Eng_m_8707.wav - 285313 records in current file
# Processed Tam_0019_Eng_m_8708.wav - 286567 records in current file
# Processed Tam_0019_Eng_m_8709.wav - 287802 records in current file
# Processed Tam_0019_Eng_m_8710.wav - 289815 records in current file
# Processed Tam_0019_Eng_m_8711.wav - 290315 records in current file
# Processed Tam_0019_Eng_m_8712.wav - 291144 records in current file
# Processed Tam_0019_Eng_m_8713.wav - 292688 records in current file
# Processed Tam_0019_Eng_m_8714.wav - 295317 records in current file
# Processed Tam_0019_Eng_m_8715.wav - 296186 records in current file
# Processed Tam_0019_Eng_m_8716.wav - 296940 records in current file
# Processed Tam_0019_Eng_m_8717.wav - 297875 records in current file
# Processed Tam_0019_Eng_m_8718.wav - 298988 records in current file
# Processed Tam_0019_Eng_m_8719.wav - 300457 records in current file
# Processed Tam_0019_Eng_m_8720.wav - 301458 records in current file
# Processed Tam_0019_Eng_m_8721.wav - 302715 records in current file
# Processed Tam_0019_Eng_m_8722.wav - 303247 records in current file
# Processed Tam_0019_Eng_m_8723.wav - 303701 records in current file
# Processed Tam_0019_Eng_m_8724.wav - 304980 records in current file
# Processed Tam_0019_Eng_m_8725.wav - 305530 records in current file
# Processed Tam_0019_Eng_m_8726.wav - 306577 records in current file
# Processed Tam_0021_Eng_f_0000.wav - 307081 records in current file
# Processed Tam_0021_Eng_f_0001.wav - 307531 records in current file
# Processed Tam_0021_Eng_f_0002.wav - 308235 records in current file
# Processed Tam_0021_Eng_f_0003.wav - 309648 records in current file
# Processed Tam_0021_Eng_f_0004.wav - 310323 records in current file
# Processed Tam_0021_Eng_f_0005.wav - 310955 records in current file
# Processed Tam_0021_Eng_f_8762.wav - 312437 records in current file
# Processed Tam_0021_Eng_f_8763.wav - 313456 records in current file
# Processed Tam_0021_Eng_f_8764.wav - 314972 records in current file
# Processed Tam_0021_Eng_f_8765.wav - 317947 records in current file
# Processed Tam_0021_Eng_f_8766.wav - 319641 records in current file
# Processed Tam_0021_Eng_f_8767.wav - 320954 records in current file
# Processed Tam_0021_Eng_f_8768.wav - 323676 records in current file
# Processed Tam_0021_Eng_f_8769.wav - 325476 records in current file
# Processed Tam_0021_Eng_f_8770.wav - 327176 records in current file
# Processed Tam_0021_Eng_f_8771.wav - 328039 records in current file
# Processed Tam_0021_Eng_f_8772.wav - 330327 records in current file
# Processed Tam_0021_Eng_f_8773.wav - 333127 records in current file
# Processed Tam_0021_Eng_f_8774.wav - 335546 records in current file
# Processed Tam_0021_Eng_f_8775.wav - 337381 records in current file
# Processed Tam_0021_Eng_f_8776.wav - 338775 records in current file
# Processed Tam_0021_Eng_f_8777.wav - 341885 records in current file
# Processed Tam_0021_Eng_f_8778.wav - 344595 records in current file
# Processed Tam_0021_Eng_f_8779.wav - 345777 records in current file
# Processed Tam_0021_Eng_f_8780.wav - 346478 records in current file
# Processed Tam_0021_Eng_f_8781.wav - 347263 records in current file
# Processed Tam_0021_Eng_f_8782.wav - 348373 records in current file
# Processed Tam_0021_Eng_f_8783.wav - 350483 records in current file
# Processed Tam_0021_Eng_f_8784.wav - 352327 records in current file
# Processed Tam_0021_Eng_f_8785.wav - 352824 records in current file
# Processed Tam_0021_Eng_f_8786.wav - 354759 records in current file
# Processed Tam_0021_Eng_f_8787.wav - 355513 records in current file
# Processed Tam_0021_Eng_f_8788.wav - 357142 records in current file
# Processed Tam_0021_Eng_f_8789.wav - 358755 records in current file
# Processed Tam_0021_Eng_f_8790.wav - 359190 records in current file
# Processed Tam_0021_Eng_f_8791.wav - 360703 records in current file
# Processed Tam_0021_Eng_f_8792.wav - 362225 records in current file
# Processed Tam_0021_Eng_f_8793.wav - 363497 records in current file
# Processed Tam_0021_Eng_f_8794.wav - 364194 records in current file
# Processed Tam_0022_Eng_f_0000.wav - 364823 records in current file
# Processed Tam_0022_Eng_f_0001.wav - 365420 records in current file
# Processed Tam_0022_Eng_f_0002.wav - 366245 records in current file
# Processed Tam_0022_Eng_f_0003.wav - 367396 records in current file
# Processed Tam_0022_Eng_f_0004.wav - 368028 records in current file
# Processed Tam_0022_Eng_f_0005.wav - 368641 records in current file
# Processed Tam_0022_Eng_f_8795.wav - 369548 records in current file
# Processed Tam_0022_Eng_f_8796.wav - 370955 records in current file
# Processed Tam_0022_Eng_f_8797.wav - 372537 records in current file
# Processed Tam_0022_Eng_f_8798.wav - 373869 records in current file
# Processed Tam_0022_Eng_f_8799.wav - 375276 records in current file
# Processed Tam_0022_Eng_f_8800.wav - 376336 records in current file
# Processed Tam_0022_Eng_f_8801.wav - 378443 records in current file
# Processed Tam_0022_Eng_f_8802.wav - 379322 records in current file
# Processed Tam_0022_Eng_f_8803.wav - 380188 records in current file
# Processed Tam_0022_Eng_f_8804.wav - 382648 records in current file
# Processed Tam_0022_Eng_f_8805.wav - 384664 records in current file
# Processed Tam_0022_Eng_f_8806.wav - 385896 records in current file
# Processed Tam_0022_Eng_f_8807.wav - 387515 records in current file
# Processed Tam_0022_Eng_f_8808.wav - 388469 records in current file
# Processed Tam_0022_Eng_f_8809.wav - 389829 records in current file
# Processed Tam_0022_Eng_f_8810.wav - 391301 records in current file
# Processed Tam_0022_Eng_f_8811.wav - 394273 records in current file
# Processed Tam_0022_Eng_f_8812.wav - 396208 records in current file
# Processed Tam_0022_Eng_f_8813.wav - 397849 records in current file
# Processed Tam_0022_Eng_f_8814.wav - 398943 records in current file
# Processed Tam_0022_Eng_f_8815.wav - 400525 records in current file
# Processed Tam_0022_Eng_f_8816.wav - 402088 records in current file
# Processed Tam_0022_Eng_f_8817.wav - 402598 records in current file
# Processed Tam_0022_Eng_f_8818.wav - 403155 records in current file
# Processed Tam_0022_Eng_f_8819.wav - 405043 records in current file
# Processed Tam_0022_Eng_f_8820.wav - 405615 records in current file
# Processed Tam_0022_Eng_f_8821.wav - 406437 records in current file
# Processed Tam_0022_Eng_f_8822.wav - 407759 records in current file
# Processed Tam_0022_Eng_f_8823.wav - 408872 records in current file
# Processed Tam_0022_Eng_f_8824.wav - 410094 records in current file
# Processed Tam_0022_Eng_f_8825.wav - 410448 records in current file
# Processed Tam_0022_Eng_f_8826.wav - 411014 records in current file
# Processed Tam_0022_Eng_f_8827.wav - 412177 records in current file
# Processed Tam_0022_Eng_f_8828.wav - 412906 records in current file
# Processed Tam_0023_Eng_f_0000.wav - 413610 records in current file
# Processed Tam_0023_Eng_f_0001.wav - 414192 records in current file
# Processed Tam_0023_Eng_f_0002.wav - 415061 records in current file
# Processed Tam_0023_Eng_f_0003.wav - 416318 records in current file
# Processed Tam_0023_Eng_f_0004.wav - 417034 records in current file
# Processed Tam_0023_Eng_f_0005.wav - 417728 records in current file
# Processed Tam_0023_Eng_f_8829.wav - 419463 records in current file
# Processed Tam_0023_Eng_f_8830.wav - 421289 records in current file
# Processed Tam_0023_Eng_f_8831.wav - 422918 records in current file
# Processed Tam_0023_Eng_f_8832.wav - 424406 records in current file
# Processed Tam_0023_Eng_f_8833.wav - 426913 records in current file
# Processed Tam_0023_Eng_f_8834.wav - 428567 records in current file
# Processed Tam_0023_Eng_f_8835.wav - 430124 records in current file
# Processed Tam_0023_Eng_f_8836.wav - 432378 records in current file
# Processed Tam_0023_Eng_f_8837.wav - 433916 records in current file
# Processed Tam_0023_Eng_f_8838.wav - 435276 records in current file
# Processed Tam_0023_Eng_f_8839.wav - 436639 records in current file
# Processed Tam_0023_Eng_f_8840.wav - 438108 records in current file
# Processed Tam_0023_Eng_f_8841.wav - 439708 records in current file
# Processed Tam_0023_Eng_f_8842.wav - 441037 records in current file
# Processed Tam_0023_Eng_f_8843.wav - 442741 records in current file
# Processed Tam_0023_Eng_f_8844.wav - 443951 records in current file
# Processed Tam_0023_Eng_f_8845.wav - 445305 records in current file
# Processed Tam_0023_Eng_f_8846.wav - 446568 records in current file
# Processed Tam_0023_Eng_f_8847.wav - 448197 records in current file
# Processed Tam_0023_Eng_f_8848.wav - 450173 records in current file
# Processed Tam_0023_Eng_f_8849.wav - 451595 records in current file
# Processed Tam_0023_Eng_f_8850.wav - 452833 records in current file
# Processed Tam_0023_Eng_f_8851.wav - 453427 records in current file
# Processed Tam_0023_Eng_f_8852.wav - 454543 records in current file
# Processed Tam_0023_Eng_f_8853.wav - 454890 records in current file
# Processed Tam_0023_Eng_f_8854.wav - 455494 records in current file
# Processed Tam_0023_Eng_f_8855.wav - 456304 records in current file
# Processed Tam_0023_Eng_f_8856.wav - 457589 records in current file
# Processed Tam_0023_Eng_f_8857.wav - 458702 records in current file
# Processed Tam_0023_Eng_f_8858.wav - 459884 records in current file
# Processed Tam_0023_Eng_f_8859.wav - 460269 records in current file
# Processed Tam_0023_Eng_f_8860.wav - 461091 records in current file
# Processed Tam_0023_Eng_f_8861.wav - 461982 records in current file
# Processed Tam_0027_Eng_f_0000.wav - 462611 records in current file
# Processed Tam_0027_Eng_f_0001.wav - 463193 records in current file
# Processed Tam_0027_Eng_f_0002.wav - 464056 records in current file
# Processed Tam_0027_Eng_f_0003.wav - 465256 records in current file
# Processed Tam_0027_Eng_f_0004.wav - 465956 records in current file
# Processed Tam_0027_Eng_f_0005.wav - 466575 records in current file
# Processed Tam_0027_Eng_f_8965.wav - 468207 records in current file
# Processed Tam_0027_Eng_f_8966.wav - 469445 records in current file
# Processed Tam_0027_Eng_f_8967.wav - 470399 records in current file
# Processed Tam_0027_Eng_f_8968.wav - 471693 records in current file
# Processed Tam_0027_Eng_f_8969.wav - 473006 records in current file
# Processed Tam_0027_Eng_f_8970.wav - 474360 records in current file
# Processed Tam_0027_Eng_f_8971.wav - 476360 records in current file
# Processed Tam_0027_Eng_f_8972.wav - 477210 records in current file
# Processed Tam_0027_Eng_f_8973.wav - 478554 records in current file
# Processed Tam_0027_Eng_f_8974.wav - 479386 records in current file
# Processed Tam_0027_Eng_f_8975.wav - 480543 records in current file
# Processed Tam_0027_Eng_f_8976.wav - 482253 records in current file
# Processed Tam_0027_Eng_f_8977.wav - 483488 records in current file
# Processed Tam_0027_Eng_f_8978.wav - 484882 records in current file
# Processed Tam_0027_Eng_f_8979.wav - 486414 records in current file
# Processed Tam_0027_Eng_f_8980.wav - 487558 records in current file
# Processed Tam_0027_Eng_f_8981.wav - 489333 records in current file
# Processed Tam_0027_Eng_f_8982.wav - 490827 records in current file
# Processed Tam_0027_Eng_f_8983.wav - 491815 records in current file
# Processed Tam_0027_Eng_f_8984.wav - 493200 records in current file
# Processed Tam_0027_Eng_f_8985.wav - 493879 records in current file
# Processed Tam_0027_Eng_f_8986.wav - 495183 records in current file
# Processed Tam_0027_Eng_f_8987.wav - 496140 records in current file
# Processed Tam_0027_Eng_f_8988.wav - 497122 records in current file
# Processed Tam_0027_Eng_f_8989.wav - 498332 records in current file
# Processed Tam_0027_Eng_f_8990.wav - 499239 records in current file
# Processed Tam_0027_Eng_f_8991.wav - 500264 records in current file
# Processed Tam_0027_Eng_f_8992.wav - 500858 records in current file
# Processed Tam_0027_Eng_f_8993.wav - 501602 records in current file
# Processed Tam_0027_Eng_f_8994.wav - 502081 records in current file
# Processed Tam_0027_Eng_f_8995.wav - 502738 records in current file
# Processed Tam_0027_Eng_f_8996.wav - 503826 records in current file
# Processed Tam_0033_Eng_f_0000.wav - 504608 records in current file
# Processed Tam_0033_Eng_f_0001.wav - 505283 records in current file
# Processed Tam_0033_Eng_f_0002.wav - 506271 records in current file
# Processed Tam_0033_Eng_f_0003.wav - 507534 records in current file
# Processed Tam_0033_Eng_f_0004.wav - 508266 records in current file
# Processed Tam_0033_Eng_f_0005.wav - 508913 records in current file
# Processed Tam_0033_Eng_f_9177.wav - 509704 records in current file
# Processed Tam_0033_Eng_f_9178.wav - 510679 records in current file
# Processed Tam_0033_Eng_f_9179.wav - 511533 records in current file
# Processed Tam_0033_Eng_f_9180.wav - 512283 records in current file
# Processed Tam_0033_Eng_f_9181.wav - 513287 records in current file
# Processed Tam_0033_Eng_f_9182.wav - 514100 records in current file
# Processed Tam_0033_Eng_f_9183.wav - 514860 records in current file
# Processed Tam_0033_Eng_f_9184.wav - 515523 records in current file
# Processed Tam_0033_Eng_f_9185.wav - 517117 records in current file
# Processed Tam_0033_Eng_f_9186.wav - 518539 records in current file
# Processed Tam_0033_Eng_f_9187.wav - 519333 records in current file
# Processed Tam_0033_Eng_f_9188.wav - 520008 records in current file
# Processed Tam_0033_Eng_f_9189.wav - 520946 records in current file
# Processed Tam_0033_Eng_f_9190.wav - 521687 records in current file
# Processed Tam_0033_Eng_f_9191.wav - 523106 records in current file
# Processed Tam_0033_Eng_f_9192.wav - 523944 records in current file
# Processed Tam_0033_Eng_f_9193.wav - 524948 records in current file
# Processed Tam_0033_Eng_f_9194.wav - 526395 records in current file
# Processed Tam_0033_Eng_f_9195.wav - 527677 records in current file
# Processed Tam_0033_Eng_f_9196.wav - 529406 records in current file
# Processed Tam_0033_Eng_f_9197.wav - 530432 records in current file
# Processed Tam_0033_Eng_f_9198.wav - 531929 records in current file
# Processed Tam_0033_Eng_f_9199.wav - 532936 records in current file
# Processed Tam_0033_Eng_f_9200.wav - 534615 records in current file
# Processed Tam_0033_Eng_f_9201.wav - 535747 records in current file
# Processed Tam_0033_Eng_f_9202.wav - 536457 records in current file
# Processed Tam_0033_Eng_f_9203.wav - 537342 records in current file
# Processed Tam_0033_Eng_f_9204.wav - 537902 records in current file
# Processed Tam_0033_Eng_f_9205.wav - 538756 records in current file
# Processed Tam_0033_Eng_f_9206.wav - 539653 records in current file
# Processed Tam_0033_Eng_f_9207.wav - 540182 records in current file
# Processed Tam_0033_Eng_f_9208.wav - 541251 records in current file
# Processed Tam_0033_Eng_f_9209.wav - 542470 records in current file
# Processed Tam_0033_Eng_f_9210.wav - 543286 records in current file
# Processed Tam_0034_Eng_m_0000.wav - 544005 records in current file
# Processed Tam_0034_Eng_m_0001.wav - 544640 records in current file
# Processed Tam_0034_Eng_m_0002.wav - 545550 records in current file
# Processed Tam_0034_Eng_m_0003.wav - 546904 records in current file
# Processed Tam_0034_Eng_m_0004.wav - 547639 records in current file
# Processed Tam_0034_Eng_m_0005.wav - 548258 records in current file
# Processed Tam_0034_Eng_m_9211.wav - 549996 records in current file
# Processed Tam_0034_Eng_m_9212.wav - 551306 records in current file
# Processed Tam_0034_Eng_m_9213.wav - 552156 records in current file
# Processed Tam_0034_Eng_m_9214.wav - 553756 records in current file
# Processed Tam_0034_Eng_m_9215.wav - 555385 records in current file
# Processed Tam_0034_Eng_m_9216.wav - 556660 records in current file
# Processed Tam_0034_Eng_m_9217.wav - 557936 records in current file
# Processed Tam_0034_Eng_m_9218.wav - 558783 records in current file
# Processed Tam_0034_Eng_m_9219.wav - 559849 records in current file
# Processed Tam_0034_Eng_m_9220.wav - 560803 records in current file
# Processed Tam_0034_Eng_m_9221.wav - 562300 records in current file
# Processed Tam_0034_Eng_m_9222.wav - 562841 records in current file
# Processed Tam_0034_Eng_m_9223.wav - 564438 records in current file
# Processed Tam_0034_Eng_m_9224.wav - 567957 records in current file
# Processed Tam_0034_Eng_m_9225.wav - 570164 records in current file
# Processed Tam_0034_Eng_m_9226.wav - 572468 records in current file
# Processed Tam_0034_Eng_m_9227.wav - 574394 records in current file
# Processed Tam_0034_Eng_m_9228.wav - 575798 records in current file
# Processed Tam_0034_Eng_m_9229.wav - 578177 records in current file
# Processed Tam_0034_Eng_m_9230.wav - 580012 records in current file
# Processed Tam_0034_Eng_m_9231.wav - 580759 records in current file
# Processed Tam_0034_Eng_m_9232.wav - 581284 records in current file
# Processed Tam_0034_Eng_m_9233.wav - 582516 records in current file
# Processed Tam_0034_Eng_m_9234.wav - 584298 records in current file
# Processed Tam_0034_Eng_m_9235.wav - 585948 records in current file
# Processed Tam_0034_Eng_m_9236.wav - 586724 records in current file
# Processed Tam_0034_Eng_m_9237.wav - 587756 records in current file
# Processed Tam_0034_Eng_m_9238.wav - 588700 records in current file
# Processed Tam_0034_Eng_m_9239.wav - 589810 records in current file
# Processed Tam_0034_Eng_m_9240.wav - 590526 records in current file
# Processed Tam_0034_Eng_m_9241.wav - 591814 records in current file
# Processed Tam_0034_Eng_m_9242.wav - 592971 records in current file
# Processed Tam_0034_Eng_m_9243.wav - 594200 records in current file
# Processed Tam_0034_Eng_m_9244.wav - 596335 records in current file
# Processed Tam_0035_Eng_f_0000.wav - 596970 records in current file
# Processed Tam_0035_Eng_f_0001.wav - 597577 records in current file
# Processed Tam_0035_Eng_f_0002.wav - 598437 records in current file
# Processed Tam_0035_Eng_f_0003.wav - 599591 records in current file
# Processed Tam_0035_Eng_f_0004.wav - 600273 records in current file
# Processed Tam_0035_Eng_f_0005.wav - 600924 records in current file
# Processed Tam_0035_Eng_f_9245.wav - 602924 records in current file
# Processed Tam_0035_Eng_f_9246.wav - 603784 records in current file
# Processed Tam_0035_Eng_f_9247.wav - 605634 records in current file
# Processed Tam_0035_Eng_f_9248.wav - 606875 records in current file
# Processed Tam_0035_Eng_f_9249.wav - 608313 records in current file
# Processed Tam_0035_Eng_f_9250.wav - 609476 records in current file
# Processed Tam_0035_Eng_f_9251.wav - 612248 records in current file
# Processed Tam_0035_Eng_f_9252.wav - 614061 records in current file
# Processed Tam_0035_Eng_f_9253.wav - 615483 records in current file
# Processed Tam_0035_Eng_f_9254.wav - 616134 records in current file
# Processed Tam_0035_Eng_f_9255.wav - 617172 records in current file
# Processed Tam_0035_Eng_f_9256.wav - 617879 records in current file
# Processed Tam_0035_Eng_f_9257.wav - 619051 records in current file
# Processed Tam_0035_Eng_f_9258.wav - 620442 records in current file
# Processed Tam_0035_Eng_f_9259.wav - 622321 records in current file
# Processed Tam_0035_Eng_f_9260.wav - 623212 records in current file
# Processed Tam_0035_Eng_f_9261.wav - 624109 records in current file
# Processed Tam_0035_Eng_f_9262.wav - 625084 records in current file
# Processed Tam_0035_Eng_f_9263.wav - 626206 records in current file
# Processed Tam_0035_Eng_f_9264.wav - 627328 records in current file
# Processed Tam_0035_Eng_f_9265.wav - 628572 records in current file
# Processed Tam_0035_Eng_f_9266.wav - 629873 records in current file
# Processed Tam_0035_Eng_f_9267.wav - 632002 records in current file
# Processed Tam_0035_Eng_f_9268.wav - 633553 records in current file
# Processed Tam_0035_Eng_f_9269.wav - 635138 records in current file
# Processed Tam_0035_Eng_f_9270.wav - 635692 records in current file
# Processed Tam_0035_Eng_f_9271.wav - 636824 records in current file
# Processed Tam_0035_Eng_f_9272.wav - 637624 records in current file
# Processed Tam_0035_Eng_f_9273.wav - 639150 records in current file
# Processed Tam_0035_Eng_f_9274.wav - 640197 records in current file
# Processed Tam_0035_Eng_f_9275.wav - 641151 records in current file
# Processed Tam_0035_Eng_f_9276.wav - 642876 records in current file
# Processed Tam_0035_Eng_f_9277.wav - 643498 records in current file
# Processed Tam_0035_Eng_f_9278.wav - 645483 records in current file
# Processed Tam_0037_Eng_m_0000.wav - 646246 records in current file
# Processed Tam_0037_Eng_m_0001.wav - 646859 records in current file
# Processed Tam_0037_Eng_m_0002.wav - 647706 records in current file
# Processed Tam_0037_Eng_m_0003.wav - 648925 records in current file
# Processed Tam_0037_Eng_m_0004.wav - 649638 records in current file
# Processed Tam_0037_Eng_m_0005.wav - 650217 records in current file
# Processed Tam_0037_Eng_m_9316.wav - 651624 records in current file
# Processed Tam_0037_Eng_m_9317.wav - 652881 records in current file
# Processed Tam_0037_Eng_m_9318.wav - 654428 records in current file
# Processed Tam_0037_Eng_m_9319.wav - 656191 records in current file
# Processed Tam_0037_Eng_m_9320.wav - 657770 records in current file
# Processed Tam_0037_Eng_m_9321.wav - 659033 records in current file
# Processed Tam_0037_Eng_m_9322.wav - 659946 records in current file
# Processed Tam_0037_Eng_m_9323.wav - 661528 records in current file
# Processed Tam_0037_Eng_m_9324.wav - 662769 records in current file
# Processed Tam_0037_Eng_m_9325.wav - 663604 records in current file
# Processed Tam_0037_Eng_m_9326.wav - 664751 records in current file
# Processed Tam_0037_Eng_m_9327.wav - 666861 records in current file
# Processed Tam_0037_Eng_m_9328.wav - 667724 records in current file
# Processed Tam_0037_Eng_m_9329.wav - 668850 records in current file
# Processed Tam_0037_Eng_m_9330.wav - 670691 records in current file
# Processed Tam_0037_Eng_m_9331.wav - 672145 records in current file
# Processed Tam_0037_Eng_m_9332.wav - 673027 records in current file
# Processed Tam_0037_Eng_m_9333.wav - 673799 records in current file
# Processed Tam_0037_Eng_m_9334.wav - 675356 records in current file
# Processed Tam_0037_Eng_m_9335.wav - 676797 records in current file
# Processed Tam_0037_Eng_m_9336.wav - 678273 records in current file
# Processed Tam_0037_Eng_m_9337.wav - 679467 records in current file
# Processed Tam_0037_Eng_m_9338.wav - 680177 records in current file
# Processed Tam_0037_Eng_m_9339.wav - 681749 records in current file
# Processed Tam_0037_Eng_m_9340.wav - 683787 records in current file
# Processed Tam_0037_Eng_m_9341.wav - 684684 records in current file
# Processed Tam_0037_Eng_m_9342.wav - 685691 records in current file
# Processed Tam_0037_Eng_m_9343.wav - 686438 records in current file
# Processed Tam_0037_Eng_m_9344.wav - 687482 records in current file
# Processed Tam_0037_Eng_m_9345.wav - 688170 records in current file
# Processed Tam_0037_Eng_m_9346.wav - 689064 records in current file
# Processed Tam_0037_Eng_m_9347.wav - 689905 records in current file
# Processed Tam_0037_Eng_m_9348.wav - 690437 records in current file
# Processed Tam_0037_Eng_m_9349.wav - 691206 records in current file
# Processed Tam_0037_Eng_m_9350.wav - 692150 records in current file
# Processed Tam_0037_Eng_m_9351.wav - 692772 records in current file
# Processed Tam_0037_Eng_m_9352.wav - 693616 records in current file
# Processed Tam_0038_Eng_m_0000.wav - 694507 records in current file
# Processed Tam_0038_Eng_m_0001.wav - 695451 records in current file
# Processed Tam_0038_Eng_m_0002.wav - 696401 records in current file
# Processed Tam_0038_Eng_m_0003.wav - 697817 records in current file
# Processed Tam_0038_Eng_m_0004.wav - 698608 records in current file
# Processed Tam_0038_Eng_m_0005.wav - 699305 records in current file
# Processed Tam_0038_Eng_m_9353.wav - 700549 records in current file
# Processed Tam_0038_Eng_m_9354.wav - 701087 records in current file
# Processed Tam_0038_Eng_m_9355.wav - 703981 records in current file
# Processed Tam_0038_Eng_m_9356.wav - 705103 records in current file
# Processed Tam_0038_Eng_m_9357.wav - 707969 records in current file
# Processed Tam_0038_Eng_m_9358.wav - 708932 records in current file
# Processed Tam_0038_Eng_m_9359.wav - 709757 records in current file
# Processed Tam_0038_Eng_m_9360.wav - 710751 records in current file
# Processed Tam_0038_Eng_m_9361.wav - 711864 records in current file
# Processed Tam_0038_Eng_m_9362.wav - 713236 records in current file
# Processed Tam_0038_Eng_m_9363.wav - 714699 records in current file
# Processed Tam_0038_Eng_m_9364.wav - 715565 records in current file
# Processed Tam_0038_Eng_m_9365.wav - 717206 records in current file
# Processed Tam_0038_Eng_m_9366.wav - 718191 records in current file
# Processed Tam_0038_Eng_m_9367.wav - 719685 records in current file
# Processed Tam_0038_Eng_m_9368.wav - 720260 records in current file
# Processed Tam_0038_Eng_m_9369.wav - 721170 records in current file
# Processed Tam_0038_Eng_m_9370.wav - 722177 records in current file
# Processed Tam_0038_Eng_m_9371.wav - 723309 records in current file
# Processed Tam_0038_Eng_m_9372.wav - 725603 records in current file
# Processed Tam_0038_Eng_m_9373.wav - 726607 records in current file
# Processed Tam_0038_Eng_m_9374.wav - 728767 records in current file
# Processed Tam_0038_Eng_m_9375.wav - 729874 records in current file
# Processed Tam_0038_Eng_m_9376.wav - 731428 records in current file
# Processed Tam_0038_Eng_m_9377.wav - 733853 records in current file
# Processed Tam_0038_Eng_m_9378.wav - 734694 records in current file
# Processed Tam_0038_Eng_m_9379.wav - 736019 records in current file
# Processed Tam_0038_Eng_m_9380.wav - 736779 records in current file
# Processed Tam_0038_Eng_m_9381.wav - 737726 records in current file
# Processed Tam_0038_Eng_m_9382.wav - 738920 records in current file
# Processed Tam_0038_Eng_m_9383.wav - 740586 records in current file
# Processed Tam_0038_Eng_m_9384.wav - 742283 records in current file
# Processed Tam_0038_Eng_m_9385.wav - 743621 records in current file
# Processed Tam_0038_Eng_m_9386.wav - 744496 records in current file
# Processed Tam_0038_Eng_m_9387.wav - 745597 records in current file
# Processed Tam_0038_Eng_m_9388.wav - 746982 records in current file
# Processed Tam_0038_Eng_m_9389.wav - 748189 records in current file
# Processed Tam_0038_Eng_m_9390.wav - 750402 records in current file
# Processed Tam_0038_Eng_m_9391.wav - 751334 records in current file
# Processed Tam_0038_Eng_m_9392.wav - 752200 records in current file
# Processed Tam_0038_Eng_m_9393.wav - 753600 records in current file
# Processed Tam_0038_Eng_m_9394.wav - 754954 records in current file
# Processed Tam_0039_Eng_m_0000.wav - 755461 records in current file
# Processed Tam_0039_Eng_m_0001.wav - 755871 records in current file
# Processed Tam_0039_Eng_m_0002.wav - 756487 records in current file
# Processed Tam_0039_Eng_m_0003.wav - 757513 records in current file
# Processed Tam_0039_Eng_m_0004.wav - 758063 records in current file
# Processed Tam_0039_Eng_m_0005.wav - 758642 records in current file
# Processed Tam_0039_Eng_m_9395.wav - 759992 records in current file
# Processed Tam_0039_Eng_m_9396.wav - 761102 records in current file
# Processed Tam_0039_Eng_m_9397.wav - 762065 records in current file
# Processed Tam_0039_Eng_m_9398.wav - 762434 records in current file
# Processed Tam_0039_Eng_m_9399.wav - 763410 records in current file
# Processed Tam_0039_Eng_m_9400.wav - 764579 records in current file
# Processed Tam_0039_Eng_m_9401.wav - 765401 records in current file
# Processed Tam_0039_Eng_m_9402.wav - 765814 records in current file
# Processed Tam_0039_Eng_m_9403.wav - 766749 records in current file
# Processed Tam_0039_Eng_m_9404.wav - 767334 records in current file
# Processed Tam_0039_Eng_m_9405.wav - 768313 records in current file
# Processed Tam_0039_Eng_m_9406.wav - 768929 records in current file
# Processed Tam_0039_Eng_m_9407.wav - 769914 records in current file
# Processed Tam_0039_Eng_m_9408.wav - 771815 records in current file
# Processed Tam_0039_Eng_m_9409.wav - 772265 records in current file
# Processed Tam_0039_Eng_m_9410.wav - 773303 records in current file
# Processed Tam_0039_Eng_m_9411.wav - 773778 records in current file
# Processed Tam_0039_Eng_m_9412.wav - 775279 records in current file
# Processed Tam_0039_Eng_m_9413.wav - 776008 records in current file
# Processed Tam_0039_Eng_m_9414.wav - 777446 records in current file
# Processed Tam_0039_Eng_m_9415.wav - 778175 records in current file
# Processed Tam_0039_Eng_m_9416.wav - 778882 records in current file
# Processed Tam_0039_Eng_m_9417.wav - 779917 records in current file
# Processed Tam_0039_Eng_m_9418.wav - 780614 records in current file
# Processed Tam_0039_Eng_m_9419.wav - 781639 records in current file
# Processed Tam_0039_Eng_m_9420.wav - 782636 records in current file
# Processed Tam_0039_Eng_m_9421.wav - 783258 records in current file
# Processed Tam_0039_Eng_m_9422.wav - 784321 records in current file
# Processed Tam_0039_Eng_m_9423.wav - 784956 records in current file
# Processed Tam_0039_Eng_m_9424.wav - 785369 records in current file
# Processed Tam_0039_Eng_m_9425.wav - 786626 records in current file
# Processed Tam_0039_Eng_m_9426.wav - 787039 records in current file
# Processed Tam_0039_Eng_m_9427.wav - 787905 records in current file
# Processed Tam_0044_Eng_m_0000.wav - 788571 records in current file
# Processed Tam_0044_Eng_m_0001.wav - 789143 records in current file
# Processed Tam_0044_Eng_m_0002.wav - 789981 records in current file
# Processed Tam_0044_Eng_m_0003.wav - 791128 records in current file
# Processed Tam_0044_Eng_m_0004.wav - 791760 records in current file
# Processed Tam_0044_Eng_m_0005.wav - 792248 records in current file
# Processed Tam_0044_Eng_m_9571.wav - 794336 records in current file
# Processed Tam_0044_Eng_m_9572.wav - 795418 records in current file
# Processed Tam_0044_Eng_m_9573.wav - 796265 records in current file
# Processed Tam_0044_Eng_m_9574.wav - 796934 records in current file
# Processed Tam_0044_Eng_m_9575.wav - 798403 records in current file
# Processed Tam_0044_Eng_m_9576.wav - 799441 records in current file
# Processed Tam_0044_Eng_m_9577.wav - 800254 records in current file
# Processed Tam_0044_Eng_m_9578.wav - 802392 records in current file
# Processed Tam_0044_Eng_m_9579.wav - 802952 records in current file
# Processed Tam_0044_Eng_m_9580.wav - 804227 records in current file
# Processed Tam_0044_Eng_m_9581.wav - 804806 records in current file
# ...
# Processed Kan_0048_Kan_m_0032.wav - 5208 records in current file
# Processed Kan_0048_Kan_m_0033.wav - 6743 records in current file
# Processed Kan_0048_Kan_m_0034.wav - 7453 records in current file
# Processed Kan_0048_Kan_m_0035.wav - 8160 records in current file
# Processed Kan_0048_Kan_m_0036.wav - 9311 records in current file
# Processed Kan_0048_Kan_m_0037.wav - 10211 records in current file
# Processed Kan_0048_Kan_m_0038.wav - 10805 records in current file
# Processed Kan_0048_Kan_m_0039.wav - 11940 records in current file
# Processed Kan_0048_Kan_m_0040.wav - 12456 records in current file
# Processed Kan_0048_Kan_m_0041.wav - 13472 records in current file
# Processed Kan_0048_Kan_m_0042.wav - 14763 records in current file
# Processed Kan_0048_Kan_m_0043.wav - 15520 records in current file
# Processed Kan_0048_Kan_m_0044.wav - 16358 records in current file
# Processed Kan_0049_Kan_f_0000.wav - 17349 records in current file
# Processed Kan_0049_Kan_f_0001.wav - 18303 records in current file
# Processed Kan_0049_Kan_f_0002.wav - 19041 records in current file
# Processed Kan_0049_Kan_f_0003.wav - 19717 records in current file
# Processed Kan_0049_Kan_f_0004.wav - 20964 records in current file
# Processed Kan_0049_Kan_f_0005.wav - 21805 records in current file
# Processed Kan_0049_Kan_f_0006.wav - 23859 records in current file
# Processed Kan_0049_Kan_f_0007.wav - 24588 records in current file
# Processed Kan_0049_Kan_f_0008.wav - 25520 records in current file
# Processed Kan_0049_Kan_f_0009.wav - 26320 records in current file
# Processed Kan_0049_Kan_f_0010.wav - 27752 records in current file
# Processed Kan_0049_Kan_f_0011.wav - 28659 records in current file
# Processed Kan_0049_Kan_f_0012.wav - 29991 records in current file
# Processed Kan_0049_Kan_f_0013.wav - 31863 records in current file
# Processed Kan_0049_Kan_f_0014.wav - 32614 records in current file
# Processed Kan_0049_Kan_f_0015.wav - 33511 records in current file
# Processed Kan_0049_Kan_f_0016.wav - 34099 records in current file
# Processed Kan_0049_Kan_f_0017.wav - 34906 records in current file
# Processed Kan_0049_Kan_f_0018.wav - 36181 records in current file
# Processed Kan_0049_Kan_f_0019.wav - 36813 records in current file
# Processed Kan_0049_Kan_f_0020.wav - 37410 records in current file
# Processed Kan_0049_Kan_f_0021.wav - 38120 records in current file
# Processed Kan_0049_Kan_f_0022.wav - 39211 records in current file
# Processed Kan_0049_Kan_f_0023.wav - 40318 records in current file
# Processed Kan_0049_Kan_f_0024.wav - 41178 records in current file
# Processed Kan_0049_Kan_f_0025.wav - 42047 records in current file
# Processed Kan_0049_Kan_f_0026.wav - 42854 records in current file
# Processed Kan_0049_Kan_f_0027.wav - 44030 records in current file
# Processed Kan_0049_Kan_f_0028.wav - 44515 records in current file
# Processed Kan_0049_Kan_f_0029.wav - 45625 records in current file
# Processed Kan_0049_Kan_f_0030.wav - 46241 records in current file
# Processed Kan_0049_Kan_f_0031.wav - 47504 records in current file
# Processed Kan_0049_Kan_f_0032.wav - 48326 records in current file
# Processed Kan_0049_Kan_f_0033.wav - 49645 records in current file
# Processed Kan_0049_Kan_f_0034.wav - 50211 records in current file
# Processed Kan_0049_Kan_f_0035.wav - 50768 records in current file
# Processed Kan_0049_Kan_f_0036.wav - 51153 records in current file
# Processed Kan_0049_Kan_f_0037.wav - 51572 records in current file
# Processed Kan_0049_Kan_f_0038.wav - 52072 records in current file
# Processed Kan_0049_Kan_f_0039.wav - 52704 records in current file
# Processed Kan_0049_Kan_f_0040.wav - 53364 records in current file
# Processed Kan_0049_Kan_f_0041.wav - 53911 records in current file
# Processed Kan_0049_Kan_f_0042.wav - 54415 records in current file
# Processed Kan_0049_Kan_f_0043.wav - 55306 records in current file
# Processed Kan_0049_Kan_f_0044.wav - 56085 records in current file
# Processed Kan_0049_Kan_f_0045.wav - 56745 records in current file
# Processed Kan_0050_Kan_f_0000.wav - 57789 records in current file
# Processed Kan_0050_Kan_f_0001.wav - 58561 records in current file
# Processed Kan_0050_Kan_f_0002.wav - 59555 records in current file
# Processed Kan_0050_Kan_f_0003.wav - 60540 records in current file
# Processed Kan_0050_Kan_f_0004.wav - 61750 records in current file
# Processed Kan_0050_Kan_f_0005.wav - 62929 records in current file
# Processed Kan_0050_Kan_f_0006.wav - 63489 records in current file
# Processed Kan_0050_Kan_f_0007.wav - 64077 records in current file
# Processed Kan_0050_Kan_f_0008.wav - 64493 records in current file
# Processed Kan_0050_Kan_f_0009.wav - 65259 records in current file
# Processed Kan_0050_Kan_f_0010.wav - 66366 records in current file
# Processed Kan_0050_Kan_f_0011.wav - 67401 records in current file
# Processed Kan_0050_Kan_f_0012.wav - 68198 records in current file
# Processed Kan_0050_Kan_f_0013.wav - 68927 records in current file
# Processed Kan_0050_Kan_f_0014.wav - 69612 records in current file
# Processed Kan_0050_Kan_f_0015.wav - 70606 records in current file
# Processed Kan_0050_Kan_f_0016.wav - 71307 records in current file
# Processed Kan_0050_Kan_f_0017.wav - 72107 records in current file
# Processed Kan_0050_Kan_f_0018.wav - 72870 records in current file
# Processed Kan_0050_Kan_f_0019.wav - 74427 records in current file
# Processed Kan_0050_Kan_f_0020.wav - 74971 records in current file
# Processed Kan_0050_Kan_f_0021.wav - 76131 records in current file
# Processed Kan_0050_Kan_f_0022.wav - 76907 records in current file
# Processed Kan_0050_Kan_f_0023.wav - 77620 records in current file
# Processed Kan_0050_Kan_f_0024.wav - 78530 records in current file
# Processed Kan_0050_Kan_f_0025.wav - 79287 records in current file
# Processed Kan_0050_Kan_f_0026.wav - 80225 records in current file
# Processed Kan_0050_Kan_f_0027.wav - 80738 records in current file
# Processed Kan_0050_Kan_f_0028.wav - 81307 records in current file
# Processed Kan_0050_Kan_f_0029.wav - 81751 records in current file
# Processed Kan_0050_Kan_f_0030.wav - 82467 records in current file
# Processed Kan_0050_Kan_f_0031.wav - 83055 records in current file
# Processed Kan_0050_Kan_f_0032.wav - 83643 records in current file
# Processed Kan_0050_Kan_f_0033.wav - 84084 records in current file
# Processed Kan_0050_Kan_f_0034.wav - 84519 records in current file
# Processed Kan_0050_Kan_f_0035.wav - 85291 records in current file
# Processed Kan_0050_Kan_f_0036.wav - 85751 records in current file
# Processed Kan_0050_Kan_f_0037.wav - 86330 records in current file
# Processed Kan_0050_Kan_f_0038.wav - 87102 records in current file
# Processed Kan_0050_Kan_f_0039.wav - 87537 records in current file
# Processed Kan_0050_Kan_f_0040.wav - 88034 records in current file
# Processed Kan_0050_Kan_f_0041.wav - 88697 records in current file
# Processed Kan_0050_Kan_f_0042.wav - 89144 records in current file
# Processed Kan_0050_Kan_f_0043.wav - 90582 records in current file
# Processed Kan_0050_Kan_f_0044.wav - 91223 records in current file
# Processed Kan_0053_Kan_f_0000.wav - 92117 records in current file
# Processed Kan_0053_Kan_f_0001.wav - 92864 records in current file
# Processed Kan_0053_Kan_f_0002.wav - 93546 records in current file
# Processed Kan_0053_Kan_f_0003.wav - 94212 records in current file
# Processed Kan_0053_Kan_f_0004.wav - 95125 records in current file
# Processed Kan_0053_Kan_f_0005.wav - 96319 records in current file
# Processed Kan_0053_Kan_f_0006.wav - 96960 records in current file
# Processed Kan_0053_Kan_f_0007.wav - 97661 records in current file
# Processed Kan_0053_Kan_f_0008.wav - 98568 records in current file
# Processed Kan_0053_Kan_f_0009.wav - 99972 records in current file
# Processed Kan_0053_Kan_f_0010.wav - 100785 records in current file
# Processed Kan_0053_Kan_f_0011.wav - 101604 records in current file
# Processed Kan_0053_Kan_f_0012.wav - 102783 records in current file
# Processed Kan_0053_Kan_f_0013.wav - 103287 records in current file
# Processed Kan_0053_Kan_f_0014.wav - 103984 records in current file
# Processed Kan_0053_Kan_f_0015.wav - 104663 records in current file
# Processed Kan_0053_Kan_f_0016.wav - 105613 records in current file
# Processed Kan_0053_Kan_f_0017.wav - 106701 records in current file
# Processed Kan_0053_Kan_f_0018.wav - 107770 records in current file
# Processed Kan_0053_Kan_f_0019.wav - 108496 records in current file
# Processed Kan_0053_Kan_f_0020.wav - 109522 records in current file
# Processed Kan_0053_Kan_f_0021.wav - 110363 records in current file
# Processed Kan_0053_Kan_f_0022.wav - 111279 records in current file
# Processed Kan_0053_Kan_f_0023.wav - 112208 records in current file
# Processed Kan_0053_Kan_f_0024.wav - 112930 records in current file
# Processed Kan_0053_Kan_f_0025.wav - 113755 records in current file
# Processed Kan_0053_Kan_f_0026.wav - 114768 records in current file
# Processed Kan_0053_Kan_f_0027.wav - 115325 records in current file
# Processed Kan_0053_Kan_f_0028.wav - 115879 records in current file
# Processed Kan_0053_Kan_f_0029.wav - 116348 records in current file
# Processed Kan_0053_Kan_f_0030.wav - 116949 records in current file
# Processed Kan_0053_Kan_f_0031.wav - 117493 records in current file
# Processed Kan_0053_Kan_f_0032.wav - 117934 records in current file
# Processed Kan_0053_Kan_f_0033.wav - 118656 records in current file
# Processed Kan_0053_Kan_f_0034.wav - 119288 records in current file
# Processed Kan_0053_Kan_f_0035.wav - 120204 records in current file
# Processed Kan_0053_Kan_f_0036.wav - 121023 records in current file
# Processed Kan_0053_Kan_f_0037.wav - 121530 records in current file
# Processed Kan_0053_Kan_f_0038.wav - 121890 records in current file
# Processed Kan_0053_Kan_f_0039.wav - 122281 records in current file
# Processed Kan_0053_Kan_f_0040.wav - 122960 records in current file
# Processed Kan_0053_Kan_f_0041.wav - 123342 records in current file
# Processed Kan_0053_Kan_f_0042.wav - 123827 records in current file
# Processed Kan_0053_Kan_f_0043.wav - 124399 records in current file
# Processed Kan_0053_Kan_f_0044.wav - 124881 records in current file
# Processed Kan_0053_Kan_f_0045.wav - 125582 records in current file
# Processed Kan_0054_Kan_f_0000.wav - 126608 records in current file
# Processed Kan_0054_Kan_f_0001.wav - 127474 records in current file
# Processed Kan_0054_Kan_f_0002.wav - 128162 records in current file
# Processed Kan_0054_Kan_f_0003.wav - 128941 records in current file
# Processed Kan_0054_Kan_f_0004.wav - 131029 records in current file
# Processed Kan_0054_Kan_f_0005.wav - 131811 records in current file
# Processed Kan_0054_Kan_f_0006.wav - 132993 records in current file
# Processed Kan_0054_Kan_f_0007.wav - 133843 records in current file
# Processed Kan_0054_Kan_f_0008.wav - 135197 records in current file
# Processed Kan_0054_Kan_f_0009.wav - 135938 records in current file
# Processed Kan_0054_Kan_f_0010.wav - 136513 records in current file
# Processed Kan_0054_Kan_f_0011.wav - 137239 records in current file
# Processed Kan_0054_Kan_f_0012.wav - 138011 records in current file
# Processed Kan_0054_Kan_f_0013.wav - 138568 records in current file
# Processed Kan_0054_Kan_f_0014.wav - 139244 records in current file
# Processed Kan_0054_Kan_f_0015.wav - 140379 records in current file
# Processed Kan_0054_Kan_f_0016.wav - 141076 records in current file
# Processed Kan_0054_Kan_f_0017.wav - 141845 records in current file
# Processed Kan_0054_Kan_f_0018.wav - 142446 records in current file
# Processed Kan_0054_Kan_f_0019.wav - 142996 records in current file
# Processed Kan_0054_Kan_f_0020.wav - 143784 records in current file
# Processed Kan_0054_Kan_f_0021.wav - 144603 records in current file
# Processed Kan_0054_Kan_f_0022.wav - 145294 records in current file
# Processed Kan_0054_Kan_f_0023.wav - 145963 records in current file
# Processed Kan_0054_Kan_f_0024.wav - 146607 records in current file
# Processed Kan_0054_Kan_f_0025.wav - 148039 records in current file
# Processed Kan_0054_Kan_f_0026.wav - 148818 records in current file
# Processed Kan_0054_Kan_f_0027.wav - 149359 records in current file
# Processed Kan_0054_Kan_f_0028.wav - 150344 records in current file
# Processed Kan_0054_Kan_f_0029.wav - 151248 records in current file
# Processed Kan_0054_Kan_f_0030.wav - 152627 records in current file
# Processed Kan_0054_Kan_f_0031.wav - 153728 records in current file
# Processed Kan_0054_Kan_f_0032.wav - 154735 records in current file
# Processed Kan_0054_Kan_f_0033.wav - 156148 records in current file
# Processed Kan_0054_Kan_f_0034.wav - 156998 records in current file
# Processed Kan_0054_Kan_f_0035.wav - 157733 records in current file
# Processed Kan_0054_Kan_f_0036.wav - 158434 records in current file
# Processed Kan_0054_Kan_f_0037.wav - 159109 records in current file
# Processed Kan_0054_Kan_f_0038.wav - 160106 records in current file
# Processed Kan_0054_Kan_f_0039.wav - 161203 records in current file
# Processed Kan_0054_Kan_f_0040.wav - 161875 records in current file
# Processed Kan_0054_Kan_f_0041.wav - 162554 records in current file
# Processed Kan_0054_Kan_f_0042.wav - 163301 records in current file
# Processed Kan_0055_Kan_f_0000.wav - 164336 records in current file
# Processed Kan_0055_Kan_f_0001.wav - 164977 records in current file
# Processed Kan_0055_Kan_f_0002.wav - 166096 records in current file
# Processed Kan_0055_Kan_f_0003.wav - 167046 records in current file
# Processed Kan_0055_Kan_f_0004.wav - 167678 records in current file
# Processed Kan_0055_Kan_f_0005.wav - 168328 records in current file
# Processed Kan_0055_Kan_f_0006.wav - 169069 records in current file
# Processed Kan_0055_Kan_f_0007.wav - 169904 records in current file
# Processed Kan_0055_Kan_f_0008.wav - 170629 records in current file
# Processed Kan_0055_Kan_f_0009.wav - 171476 records in current file
# Processed Kan_0055_Kan_f_0010.wav - 172183 records in current file
# Processed Kan_0055_Kan_f_0011.wav - 172790 records in current file
# Processed Kan_0055_Kan_f_0012.wav - 173631 records in current file
# Processed Kan_0055_Kan_f_0013.wav - 174978 records in current file
# Processed Kan_0055_Kan_f_0014.wav - 175447 records in current file
# Processed Kan_0055_Kan_f_0015.wav - 176135 records in current file
# Processed Kan_0055_Kan_f_0016.wav - 176817 records in current file
# Processed Kan_0055_Kan_f_0017.wav - 177964 records in current file
# Processed Kan_0055_Kan_f_0018.wav - 178839 records in current file
# Processed Kan_0055_Kan_f_0019.wav - 179693 records in current file
# Processed Kan_0055_Kan_f_0020.wav - 180590 records in current file
# Processed Kan_0055_Kan_f_0021.wav - 181322 records in current file
# Processed Kan_0055_Kan_f_0022.wav - 182085 records in current file
# Processed Kan_0055_Kan_f_0023.wav - 182776 records in current file
# Processed Kan_0055_Kan_f_0024.wav - 183614 records in current file
# Processed Kan_0055_Kan_f_0025.wav - 184655 records in current file
# Processed Kan_0055_Kan_f_0026.wav - 185471 records in current file
# Processed Kan_0055_Kan_f_0027.wav - 186172 records in current file
# Processed Kan_0055_Kan_f_0028.wav - 187176 records in current file
# Processed Kan_0055_Kan_f_0029.wav - 187942 records in current file
# Processed Kan_0055_Kan_f_0030.wav - 188405 records in current file
# Processed Kan_0055_Kan_f_0031.wav - 188874 records in current file
# Processed Kan_0055_Kan_f_0032.wav - 189334 records in current file
# Processed Kan_0055_Kan_f_0033.wav - 189809 records in current file
# Processed Kan_0055_Kan_f_0034.wav - 190416 records in current file
# Processed Kan_0055_Kan_f_0035.wav - 190766 records in current file
# Processed Kan_0055_Kan_f_0036.wav - 191410 records in current file
# Processed Kan_0055_Kan_f_0037.wav - 192092 records in current file
# Processed Kan_0055_Kan_f_0038.wav - 192677 records in current file
# Processed Kan_0055_Kan_f_0039.wav - 193202 records in current file
# Processed Kan_0055_Kan_f_0040.wav - 193849 records in current file
# Processed Kan_0055_Kan_f_0041.wav - 194456 records in current file
# Processed Kan_0055_Kan_f_0042.wav - 194960 records in current file
# Processed Kan_0055_Kan_f_0043.wav - 195548 records in current file
# Processed Kan_0055_Kan_f_0044.wav - 195995 records in current file
# Processed Kan_0055_Kan_f_0045.wav - 196470 records in current file
# Feature extraction and CSV writing completed

# %%
import pandas as pd

def remove_zero_columns_from_files(file_paths, columns_to_remove):
    for file_path in file_paths:
        # Load the CSV file into a DataFrame
        df = pd.read_csv(file_path)
        
        # Check if columns to remove exist in the DataFrame
        existing_columns_to_remove = [col for col in columns_to_remove if col in df.columns]
        
        # Drop the columns that are all zeros
        df = df.drop(columns=existing_columns_to_remove)
        
        # Save the modified DataFrame back to CSV
        df.to_csv(file_path, index=False)
        print(f"Updated file saved: {file_path}")

# List of file paths to your CSV files
file_paths = [
    r'C:\Users\deeps\VSCodeProjects\Jio_internship_project_2\audio_features1.csv',
    r'C:\Users\deeps\VSCodeProjects\Jio_internship_project_2\audio_features2.csv',
    r'C:\Users\deeps\VSCodeProjects\Jio_internship_project_2\audio_features3.csv',
    r'C:\Users\deeps\VSCodeProjects\Jio_internship_project_2\audio_features4.csv',
    r'C:\Users\deeps\VSCodeProjects\Jio_internship_project_2\audio_features5.csv',
    r'C:\Users\deeps\VSCodeProjects\Jio_internship_project_2\audio_features6.csv'
]

# List of columns that are all zeros across all files
zero_columns_across_all_files = [
    'mfcc_std_1', 'mfcc_skew_1', 'mfcc_kurt_1',
    'mfcc_kurt_2', 'mfcc_kurt_3', 'mfcc_kurt_4', 
    'mfcc_kurt_5', 'mfcc_kurt_6', 'mfcc_kurt_7', 
    'mfcc_kurt_9', 'mfcc_kurt_13','mfcc_skew_3'
]

# Remove the zero columns from all files and save them
remove_zero_columns_from_files(file_paths, zero_columns_across_all_files)
# Out:
# Updated file saved: C:\Users\deeps\VSCodeProjects\Jio_internship_project_2\audio_features1.csv
# Updated file saved: C:\Users\deeps\VSCodeProjects\Jio_internship_project_2\audio_features2.csv
# Updated file saved: C:\Users\deeps\VSCodeProjects\Jio_internship_project_2\audio_features3.csv
# Updated file saved: C:\Users\deeps\VSCodeProjects\Jio_internship_project_2\audio_features4.csv
# Updated file saved: C:\Users\deeps\VSCodeProjects\Jio_internship_project_2\audio_features5.csv
# Updated file saved: C:\Users\deeps\VSCodeProjects\Jio_internship_project_2\audio_features6.csv

# %%
import librosa
import numpy as np
import soundfile as sf

def remove_silence_and_save(input_file, output_file, top_db=20):
    # Load the audio file
    audio, sr = librosa.load(input_file, sr=None)
    
    # Remove silence from the audio
    non_silent_intervals = librosa.effects.split(audio, top_db=top_db)
    non_silent_audio = np.concatenate([audio[start:end] for start, end in non_silent_intervals])
    
    # Save the non-silent audio to a new file
    sf.write(output_file, non_silent_audio, sr)
    print(f"Processed audio saved to {output_file}")

# Usage example:
input_audio = r'C:\Users\deeps\VSCodeProjects\Jio_internship_project_2\Hindi_master\Hindi_master\English_Hindi\RECS\0002\Hin_0002_Eng_f_0000.wav'
output_audio = 'your_audio_file_no_silence.wav'
remove_silence_and_save(input_audio, output_audio)
# Out:
# Processed audio saved to your_audio_file_no_silence.wav
